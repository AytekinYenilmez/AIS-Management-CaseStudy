# %%
import pandas as pd

# Load Excel files
kundendatei_path = 'Kundendatei.xlsx'
ep_katalog_path = 'EP_Katalog.xlsx'

# Load sheets - assume first sheet for now
customer_df = pd.read_excel(kundendatei_path)
ep_catalog_df = pd.read_excel(ep_katalog_path)

# Show shapes and head
print("Customer file shape:", customer_df.shape)
print("EP catalog shape:", ep_catalog_df.shape)

customer_df.head(3)
# Out:
# Customer file shape: (973, 61)
# EP catalog shape: (695, 7)
#    WirtEinh  EQ_übergeordnet   Equipment  \
# 0     21083              NaN  1000005794
# 1     21083              NaN  1000005932
# 2     21083              NaN  1000005934
#
#                              EQ-Bezeichnung  EQ-Klasse EQ-Klasse-Bezeichnung  \
# 0  Schutzraumlüftung - Mitt.(Außer Betrieb)      31211       Lüftungsanlagen
# 1          RLT Batterieraum alt - Mittelbau      31211       Lüftungsanlagen
# 2              RLT Gleichr. alt - Mittelbau      31211       Lüftungsanlagen
#
#   Gewerk               Anlagenausprägung  EQ-Menge EQ-Merkmal_001  ...  \
# 0    RLT  Schutzraumlüft. ohne Sandfilt.         1            NaN  ...
# 1    RLT                Zu-/Abluftanlage         1            NaN  ...
# 2    RLT                Zu-/Abluftanlage         1            NaN  ...
#
#   EQ-Merkmal_043 EQ-Merkmal_044 EQ-Merkmal_045 EQ-Merkmal_046 EQ-Merkmal_047  \
# 0            NaN            NaN            NaN            NaN            NaN
# 1            NaN            NaN            NaN            NaN            NaN
# 2            NaN            NaN            NaN            NaN            NaN
#
#   EQ-Merkmal_048 EQ-Merkmal_049 EQ-Merkmal_050 EQ-Merkmal_051 EQ-Merkmal_052
# 0            NaN            NaN            NaN            NaN            NaN
# 1            NaN            NaN            NaN            NaN            NaN
# 2            NaN            NaN            NaN            NaN            NaN
#
# [3 rows x 61 columns]

# %% [markdown]
# ## EDA

# %%
# Show column names to check for typos or whitespace
print("Customer Columns:")
print(customer_df.columns.tolist())

print("\nEP Catalog Columns:")
print(ep_catalog_df.columns.tolist())
# Out:
# Customer Columns:
# ['WirtEinh', 'EQ_übergeordnet', 'Equipment', 'EQ-Bezeichnung', 'EQ-Klasse', 'EQ-Klasse-Bezeichnung', 'Gewerk', 'Anlagenausprägung', 'EQ-Menge', 'EQ-Merkmal_001', 'EQ-Merkmal_002', 'EQ-Merkmal_003', 'EQ-Merkmal_004', 'EQ-Merkmal_005', 'EQ-Merkmal_006', 'EQ-Merkmal_007', 'EQ-Merkmal_008', 'EQ-Merkmal_009', 'EQ-Merkmal_010', 'EQ-Merkmal_011', 'EQ-Merkmal_012', 'EQ-Merkmal_013', 'EQ-Merkmal_014', 'EQ-Merkmal_015', 'EQ-Merkmal_016', 'EQ-Merkmal_017', 'EQ-Merkmal_018', 'EQ-Merkmal_019', 'EQ-Merkmal_020', 'EQ-Merkmal_021', 'EQ-Merkmal_022', 'EQ-Merkmal_023', 'EQ-Merkmal_024', 'EQ-Merkmal_025', 'EQ-Merkmal_026', 'EQ-Merkmal_027', 'EQ-Merkmal_028', 'EQ-Merkmal_029', 'EQ-Merkmal_030', 'EQ-Merkmal_031', 'EQ-Merkmal_032', 'EQ-Merkmal_033', 'EQ-Merkmal_034', 'EQ-Merkmal_035', 'EQ-Merkmal_036', 'EQ-Merkmal_037', 'EQ-Merkmal_038', 'EQ-Merkmal_039', 'EQ-Merkmal_040', 'EQ-Merkmal_041', 'EQ-Merkmal_042', 'EQ-Merkmal_043', 'EQ-Merkmal_044', 'EQ-Merkmal_045', 'EQ-Merkmal_046', 'EQ-Merkmal_047', 'EQ-Merkmal_048', 'EQ-Merkmal_049', 'EQ-Merkmal_050', 'EQ-Merkmal_051', 'EQ-Merkmal_052']
#
# EP Catalog Columns:
# ['Unnamed: 0', 'OZ', 'Art', 'Menge', 'Einheit', 'Kurztext / Bezeichnung', 'Artikelnummer']

# %%
import re

def extract_kostengruppe(merkmal):
    if pd.isnull(merkmal):
        return None
    match = re.search(r'Kostengruppe DIN 276-1:\s*(\d{3})', str(merkmal))
    if match:
        return match.group(1)
    return None


# Look through all EQ-Merkmal columns to find a Kostengruppe
def search_kostengruppe_in_all(row):
    for col in row.index:
        if 'EQ-Merkmal' in col:
            match = extract_kostengruppe(row[col])
            if match:
                return match
    return None

# Apply row-wise
customer_df['Extracted_Kostengruppe'] = customer_df.apply(search_kostengruppe_in_all, axis=1)

# Check again
customer_df[['EQ-Bezeichnung', 'Extracted_Kostengruppe']].head(10)
# Out:
#                              EQ-Bezeichnung Extracted_Kostengruppe
# 0  Schutzraumlüftung - Mitt.(Außer Betrieb)                    431
# 1          RLT Batterieraum alt - Mittelbau                    431
# 2              RLT Gleichr. alt - Mittelbau                    431
# 3   Gebäude-Blitzschutz-, Erdungsanl., Pot.                    446
# 4               Beschallungs-/Sprechanlagen                    454
# 5         WTA Entwässerungspumpen, ortsfest                    411
# 6             Niederspannungsleitungsanlage                    444
# 7                Innenbeleuchtung, ortsfest                    445
# 8                       Wasserverteilanlage                    412
# 9                          Laufkatzenanlage                    465

# %%
has_kgr = customer_df['Extracted_Kostengruppe'].notnull().sum()
no_kgr = customer_df['Extracted_Kostengruppe'].isnull().sum()

print(f"✅ Found Kostengruppe for {has_kgr} systems")
print(f"❌ Missing Kostengruppe for {no_kgr} systems")
# Out:
# ✅ Found Kostengruppe for 913 systems
# ❌ Missing Kostengruppe for 60 systems

# %%
def extract_ep_group_prefix(artnr):
    if pd.isnull(artnr):
        return None
    match = re.match(r'(\d{3})', str(artnr))
    return match.group(1) if match else None

# Drop rows with missing Artikelnummer — these are just catalog section headers
ep_items_df = ep_catalog_df.dropna(subset=['Artikelnummer']).copy()

# Re-extract group codes just on cleaned data
ep_items_df['GroupCode'] = ep_items_df['Artikelnummer'].apply(extract_ep_group_prefix)


# Let's see how many unique groups exist
print("Unique EP Catalog Group Codes:", ep_items_df['GroupCode'].nunique())
# Out:
# Unique EP Catalog Group Codes: 43

# %%
# Now you should see only actual items
ep_items_df[['Kurztext / Bezeichnung', 'Artikelnummer', 'GroupCode']].head(10)
# Out:
#                                Kurztext / Bezeichnung        Artikelnummer  \
# 3   334 - Fenster mit Kipp- oder Drehflügel - kraf...  334.01.01.000.01.00
# 4   334 - Fenster mit Kipp- oder Drehflügel - nich...  334.01.01.000.02.00
# 5   334 - Hochwasserschutzfenster - nicht kraftbet...  334.01.02.000.01.00
# 6   334 - Falttor - kraftbetrieben - Breite < 8 m;...  334.02.01.000.01.01
# 7   334 - Falttor - nicht kraftbetrieben - Breite ...  334.02.01.000.02.01
# 8   334 - Rolltore / Rollgittertore - kraftbetrieb...  334.02.01.000.03.01
# 9   334 - Rolltore / Rollgittertore - nicht kraftb...  334.02.01.000.04.01
# 10  334 - Schiebetore (inkl. Feststellanlage) - kr...  334.02.01.000.05.01
# 11  334 - Schiebetore (inkl. Feststellanlage) - ni...  334.02.01.000.06.01
# 12  334 - Schiebetore (inkl. Feststellanlage) - kr...  334.02.01.000.07.01
#
#    GroupCode
# 3        334
# 4        334
# 5        334
# 6        334
# 7        334
# 8        334
# 9        334
# 10       334
# 11       334
# 12       334

# %%
import json
import re
import pandas as pd
from collections import defaultdict

class CatalogueParser:
    def __init__(self):
        self.tree = defaultdict(dict)
        
    def parse_catalogue_dataframe(self, df, description_col=None, article_col=None):
        """
        Parse the catalogue data from pandas DataFrame
        
        Args:
            df (pd.DataFrame): DataFrame containing catalogue data
            description_col (str): Name of the description column (auto-detected if None)
            article_col (str): Name of the article number column (auto-detected if None)
        
        Returns:
            dict: Hierarchical tree structure
        """
        # Auto-detect column names if not provided
        if description_col is None:
            # Look for common description column names
            desc_candidates = ['Kurztext / Bezeichnung', 'Kurztext', 'Bezeichnung', 'Description', 'Item']
            for col in df.columns:
                if any(candidate.lower() in col.lower() for candidate in desc_candidates):
                    description_col = col
                    break
            if description_col is None:
                description_col = df.columns[0]  # Use first column as fallback
        
        if article_col is None:
            # Look for common article number column names
            article_candidates = ['Artikelnummer', 'Article', 'Number', 'Code', 'ID']
            for col in df.columns:
                if any(candidate.lower() in col.lower() for candidate in article_candidates):
                    article_col = col
                    break
            if article_col is None:
                article_col = df.columns[1] if len(df.columns) > 1 else df.columns[0]
        
        print(f"Using columns: Description='{description_col}', Article='{article_col}'")
        
        # Process each row
        for idx, row in df.iterrows():
            description = str(row[description_col]).strip() if pd.notna(row[description_col]) else ""
            article_number = str(row[article_col]).strip() if pd.notna(row[article_col]) else ""
            
            # Skip empty rows, headers, and rows without article numbers
            if (description and article_number and 
                article_number != 'nan' and 
                not description.startswith('Wartung') and
                not description.lower().startswith('kurztext')):
                
                self.parse_item(description, article_number)
        
        return dict(self.tree)
    
    def parse_catalogue_data(self, data_text):
        """
        Parse the catalogue data from text format (kept for backward compatibility)
        
        Args:
            data_text (str): Raw catalogue data as text
        
        Returns:
            dict: Hierarchical tree structure
        """
        lines = data_text.strip().split('\n')
        
        for line in lines:
            if '\t' in line and line.strip():
                # Split by tab to separate description and article number
                parts = line.strip().split('\t')
                if len(parts) >= 2:
                    description = parts[0].strip()
                    article_number = parts[1].strip() if parts[1].strip() else None
                    
                    # Skip header lines and category headers without article numbers
                    if description and article_number and not description.startswith('Wartung'):
                        self.parse_item(description, article_number)
        
        return dict(self.tree)
    
    def parse_item(self, description, article_number):
        """
        Parse individual item description and create hierarchical structure
        
        Args:
            description (str): Item description
            article_number (str): Article number
        """
        # Remove leading numbers and dashes (e.g., "334 - ")
        cleaned_desc = re.sub(r'^\d+\s*-\s*', '', description).strip()
        
        # Split by " - " to get different levels
        parts = [part.strip() for part in cleaned_desc.split(' - ')]
        
        if not parts:
            return
        
        # First part is usually the main category
        main_category = parts[0]
        
        # Process the rest of the description
        if len(parts) > 1:
            # Join the remaining parts and parse them
            detail_description = ' - '.join(parts[1:])
            hierarchy = self.extract_hierarchy(detail_description)
        else:
            hierarchy = []
        
        # Build the tree structure
        self.build_tree_path(main_category, hierarchy, article_number)
    
    def extract_hierarchy(self, description):
        """
        Extract hierarchical information from item description
        
        Args:
            description (str): Detailed description
        
        Returns:
            list: List of hierarchical levels
        """
        hierarchy = []
        
        # Common patterns to identify different levels
        patterns = {
            'type': r'^([^-;]+?)(?:\s*-\s*|\s*;\s*|$)',
            'power': r'(kraftbetrieben|nicht kraftbetrieben|elektrisch|mechanisch)',
            'function': r'(mit|ohne)\s+(Brand-?/?Rauchschutzfunktion|Fluchtwegsfunktion|Brandschutzfunktion)',
            'wings': r'(\d+-flüglig)',
            'size': r'(Breite\s*[<>]\s*\d+\s*m[^;]*|Höhe\s*[<>]\s*\d+\s*m[^;]*|Einbauhöhe[^;]*|Innendurchmesser[^;]*|Dachfläche[^;]*)',
        }
        
        # Extract main type/category
        type_match = re.search(patterns['type'], description)
        if type_match:
            main_type = type_match.group(1).strip()
            if main_type and not any(x in main_type.lower() for x in ['kraftbetrieben', 'elektrisch', 'mechanisch']):
                hierarchy.append(('type', main_type))
        
        # Extract power/operation method
        power_match = re.search(patterns['power'], description)
        if power_match:
            hierarchy.append(('power', power_match.group(1)))
        
        # Extract function (Brand/Rauch/Fluchtweg)
        function_match = re.search(patterns['function'], description)
        if function_match:
            function_desc = f"{function_match.group(1)} {function_match.group(2)}"
            hierarchy.append(('function', function_desc))
        
        # Extract wings information
        wings_match = re.search(patterns['wings'], description)
        if wings_match:
            hierarchy.append(('wings', wings_match.group(1)))
        
        # Extract size information
        size_match = re.search(patterns['size'], description)
        if size_match:
            hierarchy.append(('size', size_match.group(1).strip()))
        
        # Handle special cases
        if 'Zulage' in description:
            hierarchy.append(('type', 'Zubehör'))
            if 'Feststellanlage' in description:
                hierarchy.append(('subtype', 'Feststellanlage für Brand-/Rauchschutzfunktion'))
            elif 'Motorschloss' in description:
                hierarchy.append(('subtype', 'Motorschloss'))
            elif 'Flichttürterminal' in description:
                hierarchy.append(('subtype', 'Flichttürterminal'))
            elif 'Fluchtürwächter' in description:
                hierarchy.append(('subtype', 'Fluchtürwächter'))
        
        return hierarchy
    
    def build_tree_path(self, main_category, hierarchy, article_number):
        """
        Build the tree path from main category through hierarchy to article number
        
        Args:
            main_category (str): Main category
            hierarchy (list): List of (type, value) tuples
            article_number (str): Final article number
        """
        # Ensure main category exists as a dict
        if main_category not in self.tree:
            self.tree[main_category] = {}
        elif not isinstance(self.tree[main_category], dict):
            self.tree[main_category] = {}
        
        current = self.tree[main_category]
        
        # Group hierarchy items by logical structure
        type_items = [item[1] for item in hierarchy if item[0] == 'type']
        power_items = [item[1] for item in hierarchy if item[0] == 'power']
        function_items = [item[1] for item in hierarchy if item[0] == 'function']
        wings_items = [item[1] for item in hierarchy if item[0] == 'wings']
        size_items = [item[1] for item in hierarchy if item[0] == 'size']
        subtype_items = [item[1] for item in hierarchy if item[0] == 'subtype']
        
        # Build path: type -> power -> function -> wings -> size
        path_elements = type_items + power_items + function_items + wings_items + size_items + subtype_items
        
        # Navigate/create the path
        for i, element in enumerate(path_elements):
            if element not in current:
                current[element] = {}
            elif not isinstance(current[element], dict):
                # If we hit a leaf node (string), we need to restructure
                # Save the existing value and convert to dict
                existing_value = current[element]
                current[element] = {"_direct": existing_value}
            current = current[element]
        
        # Set the article number at the end
        if path_elements:
            # Navigate back to set the final value
            target = self.tree[main_category]
            for element in path_elements[:-1]:
                target = target[element]
            
            # Check if the final element already exists
            final_element = path_elements[-1]
            if final_element in target and isinstance(target[final_element], dict):
                # If it's a dict, add the article number as a special key
                target[final_element]["_article"] = article_number
            else:
                # Direct assignment
                target[final_element] = article_number
        else:
            # Direct assignment to main category - but main category should be a dict
            # Store the article number with a special key
            if isinstance(self.tree[main_category], dict):
                self.tree[main_category]["_direct"] = article_number
            else:
                self.tree[main_category] = article_number
    
    def save_to_json(self, filename, tree_data):
        """Save the tree structure to a JSON file"""
        with open(filename, 'w', encoding='utf-8') as f:
            json.dump(tree_data, f, indent=2, ensure_ascii=False)
    
    def load_from_file(self, filename):
        """Load catalogue data from file"""
        with open(filename, 'r', encoding='utf-8') as f:
            return f.read()

class CatalogueDecisionTree:
    def __init__(self, tree_data=None):
        self.tree = tree_data or {}
    
    def load_from_json(self, filename):
        """Load tree structure from JSON file"""
        with open(filename, 'r', encoding='utf-8') as f:
            self.tree = json.load(f)
    
    def get_article_number(self, path):
        """
        Navigate through the decision tree using a list of choices
        
        Args:
            path (list): List of strings representing the path through the tree
        
        Returns:
            str: Article number if found, None otherwise
        """
        current = self.tree
        
        for choice in path:
            if isinstance(current, dict) and choice in current:
                current = current[choice]
            else:
                return None
        
        # Handle special keys for article numbers
        if isinstance(current, str):
            return current
        elif isinstance(current, dict):
            if "_article" in current:
                return current["_article"]
            elif "_direct" in current:
                return current["_direct"]
        
        return None
    
    def get_available_options(self, path=None):
        """
        Get available options at the current level of the tree
        
        Args:
            path (list): Current path in the tree (optional)
        
        Returns:
            list: Available options at the current level
        """
        if path is None:
            return list(self.tree.keys())
        
        current = self.tree
        for choice in path:
            if isinstance(current, dict) and choice in current:
                current = current[choice]
            else:
                return []
        
        if isinstance(current, dict):
            # Filter out special keys that start with underscore
            return [key for key in current.keys() if not key.startswith('_')]
        else:
            return []
    
    def find_article_numbers(self, search_term):
        """
        Search for article numbers containing specific terms
        
        Args:
            search_term (str): Term to search for
        
        Returns:
            list: List of (path, article_number) tuples
        """
        results = []
        
        def search_recursive(node, current_path):
            if isinstance(node, str):
                # This is an article number
                if any(search_term.lower() in part.lower() for part in current_path):
                    results.append((current_path.copy(), node))
            elif isinstance(node, dict):
                for key, value in node.items():
                    if key.startswith('_'):
                        # Handle special keys
                        if key == "_article" or key == "_direct":
                            if any(search_term.lower() in part.lower() for part in current_path):
                                results.append((current_path.copy(), value))
                    else:
                        search_recursive(value, current_path + [key])
        
        search_recursive(self.tree, [])
        return results
    
    def print_tree_structure(self, max_depth=3):
        """Print the tree structure for debugging"""
        def print_recursive(node, depth=0, prefix=""):
            if depth > max_depth:
                return
            
            if isinstance(node, str):
                print(f"{prefix}→ {node}")
            elif isinstance(node, dict):
                for i, (key, value) in enumerate(node.items()):
                    is_last = i == len(node) - 1
                    print(f"{prefix}{'└── ' if is_last else '├── '}{key}")
                    extension = "    " if is_last else "│   "
                    print_recursive(value, depth + 1, prefix + extension)
        
        print_recursive(self.tree)

# Example usage and testing
if __name__ == "__main__":
    
    # Method 1: Using pandas DataFrame (recommended for Excel files)
    ep_katalog_path = 'EP_Katalog.xlsx'
    
    try:
        # Read Excel file
        ep_catalog_df = pd.read_excel(ep_katalog_path)
        print("Excel file loaded successfully!")
        print(f"Shape: {ep_catalog_df.shape}")
        print(f"Columns: {ep_catalog_df.columns.tolist()}")
        print("\nFirst few rows:")
        print(ep_catalog_df.head())
        
        # Parse the catalogue from DataFrame
        parser = CatalogueParser()
        tree_data = parser.parse_catalogue_dataframe(ep_catalog_df)
        
        # Save to JSON file
        parser.save_to_json('catalogue_tree.json', tree_data)
        print("\nTree structure saved to 'catalogue_tree.json'")
        
    except FileNotFoundError:
        print(f"File {ep_katalog_path} not found. Using sample data instead.")
        
        # Method 2: Using sample text data (fallback)
        catalogue_data = """Kurztext / Bezeichnung	Artikelnummer
Wartung und Inspektion	
330 - Außenwände - Wände und Stützen, die dem Außenklima ausgesetzt sind bzw. an das Erdreich oder an andere Bauwerke grenzen	
334 - Außentüren und -fenster	
334 - Fenster mit Kipp- oder Drehflügel - kraftbetrieben	334.01.01.000.01.00
334 - Fenster mit Kipp- oder Drehflügel - nicht kraftbetrieben	334.01.01.000.02.00
334 - Hochwasserschutzfenster - nicht kraftbetrieben	334.01.02.000.01.00
334 - Falttor - kraftbetrieben - Breite < 8 m; Höhe <6 m	334.02.01.000.01.01
334 - Falttor - nicht kraftbetrieben - Breite < 8 m; Höhe <6 m	334.02.01.000.02.01
338 - Sonnenschutz - Rollläden, Markisen und Jalousien einschließlich Antrieben	
338 - Rolläden - elektrisch	338.01.01.194.01.00
338 - Rolläden - mechanisch	338.01.01.194.02.00"""
        
        # Parse the catalogue from text
        parser = CatalogueParser()
        tree_data = parser.parse_catalogue_data(catalogue_data)
        
        # Save to JSON file
        parser.save_to_json('catalogue_tree.json', tree_data)
    
    # Create decision tree instance
    decision_tree = CatalogueDecisionTree(tree_data)
    
    # Print the structure
    print("\nGenerated tree structure:")
    decision_tree.print_tree_structure()
    
    # Example searches
    print("\nExample usage:")
    print("Available main categories:", decision_tree.get_available_options())
    
    # Search for a specific item
    print("\nSearching for 'Fenster':")
    results = decision_tree.find_article_numbers('Fenster')
    for path, article_num in results:
        print(f"  Path: {' -> '.join(path)} | Article: {article_num}")
    
    # Navigate to specific item
    print("\nNavigating through tree:")
    main_cats = decision_tree.get_available_options()
    if main_cats:
        first_cat = main_cats[0]
        print(f"Options under '{first_cat}':", decision_tree.get_available_options([first_cat]))
# Out:
# Excel file loaded successfully!
# Shape: (695, 7)
# Columns: ['Unnamed: 0', 'OZ', 'Art', 'Menge', 'Einheit', 'Kurztext / Bezeichnung', 'Artikelnummer']
#
# First few rows:
#                   Unnamed: 0            OZ                 Art  Menge Einheit  \
# 0      E - Bedarfspos. o. GB           01.   NG - Normalgruppe    NaN     NaN
# 1     A - Alternativposition        01.01.   NG - Normalgruppe    NaN     NaN
# 2          G - Grundposition     01.01.01.   NG - Normalgruppe    NaN     NaN
# 3         B - Bezugsposition  01.01.01.01.  N - Normalposition    1.0     Stk
# 4  W - Wiederholungsposition  01.01.01.02.  N - Normalposition    1.0     Stk
#
#                               Kurztext / Bezeichnung        Artikelnummer
# 0                             Wartung und Inspektion                  NaN
# 1  330 - Außenwände - Wände und Stützen, die dem ...                  NaN
# 2                      334 - Außentüren und -fenster                  NaN
# 3  334 - Fenster mit Kipp- oder Drehflügel - kraf...  334.01.01.000.01.00
# 4  334 - Fenster mit Kipp- oder Drehflügel - nich...  334.01.01.000.02.00
# Using columns: Description='Kurztext / Bezeichnung', Article='Artikelnummer'
#
# Tree structure saved to 'catalogue_tree.json'
#
# Generated tree structure:
# ├── Fenster mit Kipp- oder Drehflügel
# │   ├── kraftbetrieben
# │   │   └── _article
# │   │       → 334.01.01.000.01.00
# │   └── nicht kraftbetrieben
# │       └── _article
# │           → 334.01.01.000.02.00
# ├── Hochwasserschutzfenster
# │   └── nicht kraftbetrieben
# │       └── _article
# │           → 334.01.02.000.01.00
# ├── Falttor
# │   ├── kraftbetrieben
# │   │   └── Breite < 8 m
# │   │       └── _article
# │   └── nicht kraftbetrieben
# │       └── Breite < 8 m
# │           └── _article
# ├── Rolltore / Rollgittertore
# │   ├── kraftbetrieben
# │   │   └── Breite < 8 m
# │   │       └── _article
# │   └── nicht kraftbetrieben
# │       └── Breite < 8 m
# │           └── _article
# ├── Schiebetore (inkl. Feststellanlage)
# │   ├── kraftbetrieben
# │   │   └── Breite < 8 m
# │   │       └── _article
# │   └── nicht kraftbetrieben
# │       ├── ohne Brandschutzfunktion
# │       │   └── Breite < 8 m
# │       └── mit Brandschutzfunktion
# │           └── Breite < 8 m
# ├── Schnelllauftore
# │   └── kraftbetrieben
# │       └── Breite < 8 m
# │           └── _article
# ├── Drehflügeltore (Schwenk- und Schwingtore)
# │   └── kraftbetrieben
# │       └── Breite < 8 m
# │           └── _article
# ├── Sektionaltore
# │   ├── kraftbetrieben
# │   │   └── Breite < 8 m
# │   │       └── _article
# │   └── nicht kraftbetrieben
# │       └── Breite < 8 m
# │           └── _article
# ├── Tore
# │   └── Feststellanlage für Brand
# │       └── Zubehör
# │           └── Feststellanlage für Brand-/Rauchschutzfunktion
# ├── Karusselltür (mit Fluchtwegsfunktion); kraftbetrieben
# │   ├── Innendurchmesser <= 3000 mm
# │   │   └── Innendurchmesser <= 3000 mm
# │   │       └── _article
# │   └── Innendurchmesser > 3000 bis 6000 mm
# │       └── Innendurchmesser > 3000 bis 6000 mm
# │           └── _article
# ├── Karusselltür (mit Fluchtwegsfunktion); nicht kraftbetrieben
# │   ├── Innendurchmesser <= 3000 mm
# │   │   └── Innendurchmesser <= 3000 mm
# │   │       └── _article
# │   └── Innendurchmesser > 3000  bis 6000 mm
# │       └── Innendurchmesser > 3000  bis 6000 mm
# │           └── _article
# ├── Karusselltür (ohne Fluchtwegsfunktion); kraftbetrieben
# │   ├── Innendurchmesser <= 3000 mm
# │   │   └── Innendurchmesser <= 3000 mm
# │   │       └── _article
# │   └── Innendurchmesser > 3000 bis 6000 mm
# │       └── Innendurchmesser > 3000 bis 6000 mm
# │           └── _article
# ├── Karusselltür (ohne Fluchtwegsfunktion); nicht kraftbetrieben
# │   ├── Innendurchmesser <= 3000 mm
# │   │   └── Innendurchmesser <= 3000 mm
# │   │       └── _article
# │   └── Innendurchmesser > 3000 bis 6000 mm
# │       └── Innendurchmesser > 3000 bis 6000 mm
# │           └── _article
# ├── Schiebetür (mit Fluchtwegsfunktion); kraftbetrieben ohne Brand-/ Rauchschutzfunktion
# │   ├── 1
# │   │   └── 1-flüglig
# │   │       └── _article
# │   └── 2
# │       └── 2-flüglig
# │           └── _article
# ├── Schiebetür (mit Fluchtwegsfunktion); kraftbetrieben mit Brand-/ Rauchschutzfunktion
# │   ├── 1
# │   │   └── 1-flüglig
# │   │       └── _article
# │   └── 2
# │       └── 2-flüglig
# │           └── _article
# ├── Schiebetür (mit Fluchtwegsfunktion); nicht kraftbetrieben ohne Brand-/ Rauchschutzfunktion
# │   ├── 1
# │   │   └── 1-flüglig
# │   │       └── _article
# │   └── 2
# │       └── 2-flüglig
# │           └── _article
# ├── Schiebetür (mit Fluchtwegsfunktion); nicht kraftbetrieben mit Brand-/ Rauchschutzfunktion
# │   ├── 1
# │   │   └── 1-flüglig
# │   │       └── _article
# │   └── 2
# │       └── 2-flüglig
# │           └── _article
# ├── Schiebetür (ohne Fluchtwegsfunktion); kraftbetrieben ohne Brand-/ Rauchschutzfunktion
# │   ├── 1
# │   │   └── 1-flüglig
# │   │       └── _article
# │   └── 2
# │       └── 2-flüglig
# │           └── _article
# ├── Schiebetür (ohne Fluchtwegsfunktion); kraftbetrieben mit Brand-/ Rauchschutzfunktion
# │   ├── 1
# │   │   └── 1-flüglig
# │   │       └── _article
# │   └── 2
# │       └── 2-flüglig
# │           └── _article
# ├── Schiebetür (ohne Fluchtwegsfunktion); nicht kraftbetrieben ohne Brand-/ Rauchschutzfunktion
# │   ├── 1
# │   │   └── 1-flüglig
# │   │       └── _article
# │   └── 2
# │       └── 2-flüglig
# │           └── _article
# ├── Schiebetür (ohne Fluchtwegsfunktion); nicht kraftbetrieben mit Brand-/ Rauchschutzfunktion
# │   ├── 1
# │   │   └── 1-flüglig
# │   │       └── _article
# │   └── 2
# │       └── 2-flüglig
# │           └── _article
# ├── Drehflügeltür (mit Fluchtwegsfunktion); kraftbetrieben ohne Brand-/ Rauchschutzfunktion
# │   ├── 1
# │   │   └── 1-flüglig
# │   │       └── _article
# │   └── 2
# │       └── 2-flüglig
# │           └── _article
# ├── Drehflügeltür (mit Fluchtwegsfunktion); kraftbetrieben mit Brand-/ Rauchschutzfunktion
# │   ├── 1
# │   │   └── 1-flüglig
# │   │       └── _article
# │   └── 2
# │       └── 2-flüglig
# │           └── _article
# ├── Drehflügeltür (mit Fluchtwegsfunktion); nicht kraftbetrieben ohne Brand-/ Rauchschutzfunktion
# │   ├── 1
# │   │   └── 1-flüglig
# │   │       └── _article
# │   └── 2
# │       └── 2-flüglig
# │           └── _article
# ├── Drehflügeltür (mit Fluchtwegsfunktion); nicht kraftbetrieben mit Brand-/ Rauchschutzfunktion
# │   ├── 1
# │   │   └── 1-flüglig
# │   │       └── _article
# │   └── 2
# │       └── 2-flüglig
# │           └── _article
# ├── Drehflügeltür (ohne Fluchtwegsfunktion); kraftbetrieben ohne Brand-/ Rauchschutzfunktion
# │   ├── 1
# │   │   └── 1-flüglig
# │   │       └── _article
# │   └── 2
# │       └── 2-flüglig
# │           └── _article
# ├── Drehflügeltür (ohne Fluchtwegsfunktion); kraftbetrieben mit Brand-/ Rauchschutzfunktion
# │   ├── 1
# │   │   └── 1-flüglig
# │   │       └── _article
# │   └── 2
# │       └── 2-flüglig
# │           └── _article
# ├── Drehflügeltür (ohne Fluchtwegsfunktion); nicht kraftbetrieben ohne Brand-/ Rauchschutzfunktion
# │   ├── 1
# │   │   └── 1-flüglig
# │   │       └── _article
# │   └── 2
# │       └── 2-flüglig
# │           └── _article
# ├── Drehflügeltür (ohne Fluchtwegsfunktion); nicht kraftbetrieben mit Brand-/ Rauchschutzfunktion
# │   ├── 1
# │   │   └── 1-flüglig
# │   │       └── _article
# │   └── 2
# │       └── 2-flüglig
# │           └── _article
# ├── Türen
# │   ├── Feststellanlage für Brand
# │   │   └── Zubehör
# │   │       └── Feststellanlage für Brand-/Rauchschutzfunktion
# │   ├── Motorschloss
# │   │   └── Zubehör
# │   │       └── Motorschloss
# │   ├── Flichttürterminal
# │   │   └── Zubehör
# │   │       └── Flichttürterminal
# │   └── Fluchtürwächter
# │       └── Zubehör
# │           └── Fluchtürwächter
# ├── Personenvereinzelungsanlage, Schleuse/Durchgangsschleuse
# │   └── _direct
# │       → 334.03.02.000.00.00
# ├── Rolläden
# │   ├── elektrisch
# │   │   └── _article
# │   │       → 338.01.01.194.01.00
# │   └── mechanisch
# │       └── _article
# │           → 338.01.01.194.02.00
# ├── Jalousien
# │   ├── elektrisch
# │   │   └── _article
# │   │       → 338.01.01.159.01.00
# │   └── mechanisch
# │       └── _article
# │           → 338.01.01.159.02.00
# ├── Markisen
# │   ├── elektrisch
# │   │   └── _article
# │   │       → 338.01.01.177.01.00
# │   └── mechanisch
# │       └── _article
# │           → 338.01.01.177.02.00
# ├── Raffstoreanlage
# │   ├── elektrisch
# │   │   └── _article
# │   │       → 338.01.01.187.01.00
# │   └── mechanisch
# │       └── _article
# │           → 338.01.01.187.02.00
# ├── Werbeanlagen
# │   └── _direct
# │       → 339.01.01.000.00.00
# ├── Falt- und Schiebewände
# │   ├── kraftbetrieben
# │   │   └── _article
# │   │       → 346.01.01.000.01.00
# │   └── nicht kraftbetrieben
# │       └── _article
# │           → 346.01.01.000.02.00
# ├── Lichtkuppeln / Oberlichter / Dachfenster
# │   └── elektrisch
# │       ├── Einbauhöhe <= 6 m
# │       │   └── _article
# │       └── Einbauhöhe 6 m bis 12 m
# │           └── _article
# ├── Flachdach
# │   ├── Dachfläche <= 5000 m²
# │   │   └── Dachfläche <= 5000 m²
# │   │       └── _article
# │   ├── Dachfläche > 5.000 bis 25.000 m²
# │   │   └── Dachfläche > 5.000 bis 25.000 m²
# │   │       └── _article
# │   ├── Dachfläche > 25.000 bis 50.000 m²
# │   │   └── Dachfläche > 25.000 bis 50.000 m²
# │   │       └── _article
# │   ├── Dachfläche > 50.000  bis 100.000 m²
# │   │   └── Dachfläche > 50.000  bis 100.000 m²
# │   │       └── _article
# │   └── Dachfläche > 100.000 bis 250.000 m²
# │       └── Dachfläche > 100.000 bis 250.000 m²
# │           └── _article
# ├── Rauchschutz- / Feuerschutzvorhänge / Rauchschürze
# │   ├── Breite < 5 m
# │   │   └── Breite < 5 m
# │   │       └── _article
# │   └── Breite < 8 m
# │       └── Breite < 8 m
# │           └── _article
# ├── Tritte / Leitern
# │   ├── ortsfest
# │   │   └── _article
# │   │       → 389.01.01.000.01.00
# │   └── ortsveränderlich
# │       └── _article
# │           → 389.01.01.000.02.00
# ├── Sekuranten
# │   └── _direct
# │       → 389.02.01.000.00.00
# ├── Anschlagpunkte
# │   └── _direct
# │       → 389.02.02.000.00.00
# ├── Seilsysteme
# │   └── _direct
# │       → 389.02.03.000.00.00
# ├── Schneelastwaage
# │   └── _direct
# │       → 389.03.01.000.00.00
# ├── Abwasserleitung
# │   ├── größte Nennweite <= 200 DN
# │   │   └── _article
# │   │       → 411.01.01.000.00.01
# │   ├── größte Nennweite > 200 bis <= 500 DN
# │   │   └── _article
# │   │       → 411.01.01.000.00.02
# │   └── größte Nennweite > 500 bis <= 1000 DN
# │       └── _article
# │           → 411.01.01.000.00.03
# ├── Kontroll-, Reinigungs- und Sammelschächte
# │   └── _direct
# │       → 411.01.01.171.00.00
# ├── Bodenrinnen (KGR 400)
# │   └── _direct
# │       → 411.02.01.120.00.00
# ├── Bodenrinnen (KGR 500)
# │   └── _direct
# │       → 411.02.01.119.00.00
# ├── Bodeneinläufe
# │   └── _direct
# │       → 411.02.01.118.00.00
# ├── Straßeneinlaufkästen (KGR 500)
# │   └── _direct
# │       → 411.02.01.206.00.00
# ├── Dachrinnen
# │   └── _direct
# │       → 411.02.01.126.00.00
# ├── Dacheinläufe
# │   └── _direct
# │       → 411.02.01.125.00.00
# ├── Sickerschächte
# │   └── _direct
# │       → 411.03.01.201.00.00
# ├── Rigolen
# │   └── _direct
# │       → 411.03.01.191.00.00
# ├── Leichtflüssigkeitsabscheider (Benzin/Öl)
# │   ├── Nenngröße <=2
# │   │   └── _article
# │   │       → 411.04.01.000.00.01
# │   └── Nenngröße > 2 bis 5
# │       └── _article
# │           → 411.04.01.000.00.02
# ├── Fettabscheider
# │   ├── Nenngröße <= 5
# │   │   └── _article
# │   │       → 411.04.02.000.00.01
# │   ├── Nenngröße > 5 bis 10
# │   │   └── _article
# │   │       → 411.04.02.000.00.02
# │   └── Nenngröße > 10 bis 15
# │       └── _article
# │           → 411.04.02.000.00.03
# ├── Stärkeabscheider
# │   ├── Nenngröße <=1
# │   │   └── _article
# │   │       → 411.04.03.000.00.01
# │   ├── Nenngröße > 1 bis 2
# │   │   └── _article
# │   │       → 411.04.03.000.00.02
# │   └── Nenngröße > 2 bis 5
# │       └── _article
# │           → 411.04.03.000.00.03
# ├── Neutralisationsanlage
# │   └── _direct
# │       → 411.04.04.000.00.00
# ├── Hebeanlage Einfachpumpe geschlossen
# │   ├── fäkalienfrei
# │   │   └── _article
# │   │       → 411.05.01.012.01.02
# │   └── fäkalienhaltig
# │       └── _article
# │           → 411.05.01.012.02.02
# ├── Hebeanlage Doppelpumpe geschlossen
# │   ├── fäkalienfrei
# │   │   └── _article
# │   │       → 411.05.01.012.03.03
# │   └── fäkalienhaltig
# │       └── _article
# │           → 411.05.01.012.04.03
# ├── Tauchpumpe inkl. Pumpensumpf
# │   ├── Fördermenge <= 10 m3/h
# │   │   └── _article
# │   │       → 411.05.02.000.00.01
# │   └── Fördermenge > 10 bis 50 m3/h
# │       └── _article
# │           → 411.05.02.000.00.02
# ├── Brunnenanlagen
# │   ├── Fördermenge <= 10 m3/h
# │   │   └── _article
# │   │       → 412.01.01.012.00.01
# │   ├── Fördermenge > 10 bis 50 m3/h
# │   │   └── _article
# │   │       → 412.01.01.012.00.02
# │   ├── Fördermenge > 50 bis 150 m3/h
# │   │   └── _article
# │   │       → 412.01.01.012.00.03
# │   └── Fördermenge > 150 bis 250 m3/h
# │       └── _article
# │           → 412.01.01.012.00.04
# ├── Regenwassernutzungsanlagen
# │   ├── Speichervolumen <=10 m3
# │   │   └── _article
# │   │       → 412.01.02.000.00.01
# │   ├── Speichervolumen > 10 bis 50 m3
# │   │   └── _article
# │   │       → 412.01.02.000.00.02
# │   └── Speichervolumen > 50 bis 100 m3
# │       └── _article
# │           → 412.01.02.000.00.03
# ├── Flusswasseranlagen
# │   ├── Fördermenge <= 10 m3/h
# │   │   └── _article
# │   │       → 412.01.03.000.00.01
# │   ├── Fördermenge > 10 bis 50 m3/h
# │   │   └── _article
# │   │       → 412.01.03.000.00.02
# │   ├── Fördermenge > 50 bis 150 m3/h
# │   │   └── _article
# │   │       → 412.01.03.000.00.03
# │   └── Fördermenge > 150 bis 250 m3/h
# │       └── _article
# │           → 412.01.03.000.00.04
# ├── Wasseraufbereitungsanlagen (Enthärtung)
# │   ├── einfach
# │   │   └── _article
# │   │       → 412.02.01.000.01.02
# │   └── doppelt
# │       └── _article
# │           → 412.02.01.000.02.02
# ├── Wasseraufbereitungsanlagen (Dosierung)
# │   └── _direct
# │       → 412.02.02.000.00.00
# ├── Wasseraufbereitungsanlagen (Umkehrosmose)
# │   ├── Permeatleistung <= 1 m3/h
# │   │   └── _article
# │   │       → 412.02.03.000.00.01
# │   └── Permeatleistung > 1 m3/h bis 5 m3/h
# │       └── _article
# │           → 412.02.03.000.00.02
# ├── Enteisenungs-/ Entmanganungsanlagen
# │   ├── Durchflussleistung <= 1 m3/h
# │   │   └── _article
# │   │       → 412.02.04.000.00.01
# │   └── Durchflussleistung > 1 m3/h bis 5 m3/h
# │       └── _article
# │           → 412.02.04.000.00.02
# ├── Druckerhöhungsanlagen (nicht Löschwasser)
# │   ├── Fördermenge <= 50 m3/h
# │   │   └── _article
# │   │       → 412.02.05.012.00.01
# │   ├── Fördermenge > 50 bis 150 m3/h
# │   │   └── _article
# │   │       → 412.02.05.012.00.02
# │   ├── Fördermenge > 150 bis 250 m3/h
# │   │   └── _article
# │   │       → 412.02.05.012.00.03
# │   ├── Fördermenge > 250 bis 500 m3/h
# │   │   └── _article
# │   │       → 412.02.05.012.00.04
# │   └── Fördermenge > 500 bis 1000 m3/h
# │       └── _article
# │           → 412.02.05.012.00.05
# ├── Wasserverteilung (inkl. Rohrnetz und Absperr-, Entleerungs- und Entnahmearmaturen, Druckminderung)
# │   └── _direct
# │       → 412.03.01.000.00.00
# ├── Hygienespüleinrichtungen
# │   └── _direct
# │       → 412.03.01.000.01.00
# ├── Wasserfilter
# │   └── ohne Rückspülung
# │       └── _article
# │           → 412.03.01.229.00.00
# ├── Wasserzähler
# │   └── _direct
# │       → 412.03.01.230.00.00
# ├── Durchlauferhitzer, Klein-, Wand- und Standspeicher
# │   └── _direct
# │       → 412.04.01.000.00.00
# ├── Sanitäre Einrichtungsgegenstände (Waschtisch, Urinale, WC, Duschen, Wannen, etc.)
# │   └── _direct
# │       → 412.05.01.000.00.00
# ├── Gastank oberirdisch inkl. Füll- u. Entleerungseinrichtungen
# │   ├── Nenninhalt <= 10.000 l
# │   │   └── _article
# │   │       → 413.01.01.000.01.01
# │   └── Nenninhalt > 10.000 bis 50.000 l
# │       └── _article
# │           → 413.01.01.000.01.02
# ├── Gastank unterirdisch inkl. Füll- u. Entleerungseinrichtungen
# │   ├── Nenninhalt <= 10.000 l
# │   │   └── _article
# │   │       → 413.01.01.000.02.01
# │   └── Nenninhalt > 10.000 bis 50.000 l
# │       └── _article
# │           → 413.01.01.000.02.02
# ├── Gaseinspeisung
# │   └── _direct
# │       → 413.02.01.000.00.00
# ├── Gaszähler
# │   └── _direct
# │       → 413.03.01.146.00.00
# ├── Gasregelstrecke
# │   └── _direct
# │       → 413.03.02.000.00.00
# ├── Heizöltank oberirdisch inkl. Füll- u. Entleerungseinrichtungen
# │   ├── Nenninhalt <= 10.000 l
# │   │   └── _article
# │   │       → 421.01.01.000.01.01
# │   └── Nenninhalt > 10.000 bis 50.000 l
# │       └── _article
# │           → 421.01.01.000.01.02
# ├── Heizöltank unterirdisch inkl. Füll- u. Entleerungseinrichtungen
# │   ├── Nenninhalt <= 10.000 l
# │   │   └── _article
# │   │       → 421.01.01.000.02.01
# │   └── Nenninhalt > 10.000 bis 50.000 l
# │       └── _article
# │           → 421.01.01.000.02.02
# ├── Leckageüberwachungsanlage Heizöltank
# │   └── _direct
# │       → 421.01.01.000.03.00
# ├── Heizölversorgungsleitung für Ölbrenner inkl. Armaturen
# │   └── _direct
# │       → 421.01.02.000.00.00
# ├── Fernwärmeübergabestation
# │   └── Heißwasser
# │       └── _article
# │           → 421.02.01.000.00.04
# ├── Wasserkessel (ohne Brenner)
# │   ├── Nennleistung <= 50 kW
# │   │   └── _article
# │   │       → 421.03.01.164.01.01
# │   ├── Nennleistung > 50 bis 150 kW
# │   │   └── _article
# │   │       → 421.03.01.164.01.02
# │   ├── Nennleistung > 150 bis 300 kW
# │   │   └── _article
# │   │       → 421.03.01.164.01.03
# │   ├── Nennleistung > 300 bis 500 kW
# │   │   └── _article
# │   │       → 421.03.01.164.01.04
# │   └── Nennleistung > 500 bis 800 kW
# │       └── _article
# │           → 421.03.01.164.01.05
# ├── Dampfkessel
# │   └── _direct
# │       → 421.03.01.164.02.00
# ├── Ölbrenner
# │   ├── Nennleistung <= 50 kW
# │   │   └── _article
# │   │       → 421.03.01.014.03.01
# │   ├── Nennleistung > 50 bis 150 kW
# │   │   └── _article
# │   │       → 421.03.01.014.03.02
# │   ├── Nennleistung > 150 bis 300 kW
# │   │   └── _article
# │   │       → 421.03.01.014.03.03
# │   ├── Nennleistung > 300 bis 500 kW
# │   │   └── _article
# │   │       → 421.03.01.014.03.04
# │   └── Nennleistung > 500 bis 800 kW
# │       └── _article
# │           → 421.03.01.014.03.05
# ├── atmosphärische Gasbrenner (ohne Gebläse)
# │   ├── Nennleistung <= 50 kW
# │   │   └── _article
# │   │       → 421.03.01.014.04.01
# │   ├── Nennleistung > 50 bis 150 kW
# │   │   └── _article
# │   │       → 421.03.01.014.04.02
# │   ├── Nennleistung > 150 bis 300 kW
# │   │   └── _article
# │   │       → 421.03.01.014.04.03
# │   └── Nennleistung > 300 bis 500 kW
# │       └── _article
# │           → 421.03.01.014.04.04
# ├── Gasgebläsebrenner
# │   ├── Nennleistung <= 50 kW
# │   │   └── _article
# │   │       → 421.03.01.014.05.01
# │   ├── Nennleistung > 50 bis 150 kW
# │   │   └── _article
# │   │       → 421.03.01.014.05.02
# │   ├── Nennleistung > 150 bis 300 kW
# │   │   └── _article
# │   │       → 421.03.01.014.05.03
# │   ├── Nennleistung > 300 bis 500 kW
# │   │   └── _article
# │   │       → 421.03.01.014.05.04
# │   └── Nennleistung > 500 bis 800 kW
# │       └── _article
# │           → 421.03.01.014.05.05
# ├── Brenner für Feststoffe (ausgenommen Einzelraumfeuerungsanlagen)
# │   └── _direct
# │       → 421.03.01.014.06.00
# ├── Brenner für Staubfeuerungen
# │   └── _direct
# │       → 421.03.01.014.07.00
# ├── Grundwasser-Wärmepumpen (inkl. Brunnenanlage)
# │   ├── Nennleistung <= 30 kW
# │   │   └── _article
# │   │       → 421.03.02.000.08.01
# │   ├── Nennleistung >30 bis 80 kW
# │   │   └── _article
# │   │       → 421.03.02.000.08.02
# │   ├── Nennleistung > 80 bis 150 kW
# │   │   └── _article
# │   │       → 421.03.02.000.08.03
# │   └── Nennleistung > 150 bis 250 kW
# │       └── _article
# │           → 421.03.02.000.08.04
# ├── Luft-Wärmepumpen (inkl. Verdampfer)
# │   ├── Nennleistung <= 30 kW
# │   │   └── _article
# │   │       → 421.03.02.000.09.01
# │   ├── Nennleistung > 30 bis 80 kW
# │   │   └── _article
# │   │       → 421.03.02.000.09.02
# │   ├── Nennleistung > 80 bis 150 kW
# │   │   └── _article
# │   │       → 421.03.02.000.09.03
# │   └── Nennleistung > 150 bis 250 kW
# │       └── _article
# │           → 421.03.02.000.09.04
# ├── Erd-Wärmepumpen (inkl. Erdkollektor)
# │   ├── Nennleistung <= 30 kW
# │   │   └── _article
# │   │       → 421.03.02.000.10.01
# │   └── Nennleistung >30 bis 80 kW
# │       └── _article
# │           → 421.03.02.000.10.02
# ├── Gasthermen (inkl. Brenner)
# │   ├── Nennleistung <= 30 kW
# │   │   └── _article
# │   │       → 421.03.03.000.00.01
# │   └── Nennleistung >30 bis 80 kW
# │       └── _article
# │           → 421.03.03.000.00.02
# ├── Solarthermie
# │   ├── Kollektorfläche <= 100 m2
# │   │   └── _article
# │   │       → 421.03.04.000.00.01
# │   ├── Kollektorfläche > 100 bis 500 m2
# │   │   └── _article
# │   │       → 421.03.04.000.00.02
# │   └── Kollektorfläche > 500 bis 2.500 m2
# │       └── _article
# │           → 421.03.04.000.00.03
# ├── Blockheizkraftwerk (wärmegeführt)
# │   └── _direct
# │       → 421.03.05.000.00.00
# ├── Brennstoffzellenheizgeräte
# │   └── _direct
# │       → 421.03.06.000.00.00
# ├── Elektroheizungen
# │   └── _direct
# │       → 421.03.07.000.00.00
# ├── Hellstrahler (brennerlos)
# │   ├── Nennleistung <= 15 kW
# │   │   └── _article
# │   │       → 421.03.08.000.01.01
# │   └── Nennleistung > 15 bis 40 kW
# │       └── _article
# │           → 421.03.08.000.01.02
# ├── Dunkelstrahler (inkl. Brenner)
# │   ├── Nennleistung <= 15 kW
# │   │   └── _article
# │   │       → 421.03.08.000.02.01
# │   └── Nennleistung > 15 bis 40 kW
# │       └── _article
# │           → 421.03.08.000.02.02
# ├── Einzelraumfeuerungsanlagen für feste Brennstoffe
# │   └── _direct
# │       → 421.03.09.000.00.00
# ├── Warmwasserspeicher indirekt beheizt
# │   ├── Volumen <=150 l
# │   │   └── _article
# │   │       → 421.04.01.227.01.01
# │   ├── Volumen >150 bis 500 l
# │   │   └── _article
# │   │       → 421.04.01.227.01.02
# │   ├── Volumen > 500 bis 1.000 l
# │   │   └── _article
# │   │       → 421.04.01.227.01.03
# │   └── Volumen > 1.000 bis 2.000 l
# │       └── _article
# │           → 421.04.01.227.01.04
# ├── Warmwasserspeicher direkt beheizt (inkl. Gasbrenner)
# │   ├── Volumen <=150 l
# │   │   └── _article
# │   │       → 421.04.01.227.02.01
# │   └── Volumen >150 bis 500 l
# │       └── _article
# │           → 421.04.01.227.02.02
# ├── Warmwasserspeicher direkt beheizt (elektrisch)
# │   ├── Volumen > 50 bis 150 l
# │   │   └── _article
# │   │       → 421.04.01.227.03.01
# │   ├── Volumen > 150 bis 300 l
# │   │   └── _article
# │   │       → 421.04.01.227.03.02
# │   ├── Volumen > 300 bis 500 l
# │   │   └── _article
# │   │       → 421.04.01.227.03.03
# │   └── Volumen > 500 bis 1.000 l
# │       └── _article
# │           → 421.04.01.227.03.04
# ├── Schornsteine
# │   └── _direct
# │       → 421.05.01.000.00.00
# ├── Heizungsverteiler (inkl. Entleerungen, Thermometer, Manometer, Armaturen, Ventile, Klappen, Wächter, Schmutzfänger, Umwälzpumpen, Druckausdehnungsgefäße, Nachspeiseeinrichtungen, Hydrauliche Weichen etc.)
# │   ├── Anzahl Kreise 1 bis 5
# │   │   └── _article
# │   │       → 422.01.01.154.01.02
# │   ├── Anzahl Kreise 6 bis 10
# │   │   └── _article
# │   │       → 422.01.01.154.02.02
# │   └── Anzahl Kreise 10 bis 20
# │       └── _article
# │           → 422.01.01.154.03.02
# ├── Entgasungsstation inkl. Absperrungen
# │   └── Anlagenvolumen bis 100 m3
# Arbeitsdruck bis 4,5 bar
# │       └── _article
# │           → 422.01.01.013.00.01
# ├── Plattenwärmetauscher inkl. Absperrungen
# │   ├── Nennleistung <= 50 kW
# │   │   └── _article
# │   │       → 422.01.01.005.01.01
# │   ├── Nennleistung > 50 bis 150 kW
# │   │   └── _article
# │   │       → 422.01.01.005.01.02
# │   ├── Nennleistung > 150 bis 300 kW
# │   │   └── _article
# │   │       → 422.01.01.005.01.03
# │   ├── Nennleistung > 300 bis 500 kW
# │   │   └── _article
# │   │       → 422.01.01.005.01.04
# │   ├── Nennleistung > 500 bis 1.000 kW
# │   │   └── _article
# │   │       → 422.01.01.005.01.05
# │   └── Nennleistung > 1.000 bis 2.000 kW
# │       └── _article
# │           → 422.01.01.005.01.06
# ├── Rohrbündelwärmetauscher inkl. Absperrungen
# │   ├── Nennleistung <= 50 kW
# │   │   └── _article
# │   │       → 422.01.01.005.02.01
# │   ├── Nennleistung > 50 bis 150 kW
# │   │   └── _article
# │   │       → 422.01.01.005.02.02
# │   ├── Nennleistung > 150 bis 300 kW
# │   │   └── _article
# │   │       → 422.01.01.005.02.03
# │   ├── Nennleistung > 300 bis 500 kW
# │   │   └── _article
# │   │       → 422.01.01.005.02.04
# │   ├── Nennleistung > 500 bis 1.000 kW
# │   │   └── _article
# │   │       → 422.01.01.005.02.05
# │   └── Nennleistung > 1.000 bis 2.000 kW
# │       └── _article
# │           → 422.01.01.005.02.06
# ├── Wärmemengenzähler
# │   └── _direct
# │       → 422.01.01.225.00.00
# ├── Druckhaltesysteme mit Fremddruckerzeugung (Pumpen / Kompressoren)
# │   ├── Volumen <= 300 Liter
# │   │   └── _article
# │   │       → 422.01.02.000.00.01
# │   ├── Volumen > 300 bis 1.000 Liter
# │   │   └── _article
# │   │       → 422.01.02.000.00.02
# │   └── Volumen > 1.000 bis 5.000 Liter
# │       └── _article
# │           → 422.01.02.000.00.03
# ├── Heizkörper
# │   └── _direct
# │       → 423.01.01.000.00.00
# ├── Wand- / Decken -/ Fußbodenheizung
# │   ├── Heizflächen
# │   │   └── _article
# │   │       → 423.02.01.000.00.00
# │   └── Verteiler
# │       └── _article
# │           → 423.02.02.000.00.03
# ├── Rampenheizung (wassergeführt)
# │   ├── Nennleistung <= 50 kW
# │   │   └── _article
# │   │       → 429.01.01.000.00.01
# │   └── Nennleistung > 50 bis 150 kW
# │       └── _article
# │           → 429.01.01.000.00.02
# ├── Abluftanlagen (mit bis zu einer LBF)
# │   ├── Abluft Volumenstrom <= 500 m³/h
# │   │   └── _article
# │   │       → 431.01.01.000.00.01
# │   ├── Abluft Volumenstrom > 500 bis 2.500 m³/h
# │   │   └── _article
# │   │       → 431.01.01.000.00.02
# │   ├── Abluft Volumenstrom > 2.500 bis 5.000 m³/h
# │   │   └── _article
# │   │       → 431.01.01.000.00.03
# │   ├── Abluft Volumenstrom > 5.000 bis 10.000 m³/h
# │   │   └── _article
# │   │       → 431.01.01.000.00.04
# │   ├── Abluft Volumenstrom > 10.000 bis 20.000 m³/h
# │   │   └── _article
# │   │       → 431.01.01.000.00.05
# │   ├── Abluft Volumenstrom > 20.000 bis 30.000 m³/h
# │   │   └── _article
# │   │       → 431.01.01.000.00.06
# │   ├── Abluft Volumenstrom > 30.000 bis 50.000 m³/h
# │   │   └── _article
# │   │       → 431.01.01.000.00.07
# │   ├── Abluft Volumenstrom > 50.000 bis 75.000 m³/h
# │   │   └── _article
# │   │       → 431.01.01.000.00.08
# │   └── Abluft Volumenstrom > 75.000 bis 100.000 m³/h
# │       └── _article
# │           → 431.01.01.000.00.09
# ├── Abluftanlage
# │   └── Frequenzumformer
# │       └── Zubehör
# │           └── _article
# ├── Zuluftanlagen (mit bis zu einer LBF)
# │   ├── Zuluft Volumenstrom <= 500 m³/h
# │   │   └── _article
# │   │       → 431.02.01.000.00.01
# │   ├── Zuluft Volumenstrom > 500 bis 2.500 m³/h
# │   │   └── _article
# │   │       → 431.02.01.000.00.02
# │   ├── Zuluft Volumenstrom > 2.500 bis 5.000 m³/h
# │   │   └── _article
# │   │       → 431.02.01.000.00.03
# │   ├── Zuluft Volumenstrom > 5.000 bis 10.000 m³/h
# │   │   └── _article
# │   │       → 431.02.01.000.00.04
# │   ├── Zuluft Volumenstrom > 10.000 bis 20.000 m³/h
# │   │   └── _article
# │   │       → 431.02.01.000.00.05
# │   ├── Zuluft Volumenstrom > 20.000 bis 30.000 m³/h
# │   │   └── _article
# │   │       → 431.02.01.000.00.06
# │   ├── Zuluft Volumenstrom > 30.000 bis 50.000 m³/h
# │   │   └── _article
# │   │       → 431.02.01.000.00.07
# │   ├── Zuluft Volumenstrom > 50.000 bis 75.000 m³/h
# │   │   └── _article
# │   │       → 431.02.01.000.00.08
# │   └── Zuluft Volumenstrom > 75.000 bis 100.000 m³/h
# │       └── _article
# │           → 431.02.01.000.00.09
# ├── Zuluftanlage
# │   └── Frequenzumformer
# │       └── Zubehör
# │           └── _article
# ├── Zu- und Abluftanlagen (mit bis zur einer LBF); mit WRG
# │   ├── Volumenstrom <= 500 m³/h
# │   │   └── _article
# │   │       → 431.03.01.000.01.01
# │   ├── Volumenstrom > 500 bis 2.500 m³/h
# │   │   └── _article
# │   │       → 431.03.01.000.01.02
# │   ├── Volumenstrom > 2.500 bis 5.000 m³/h
# │   │   └── _article
# │   │       → 431.03.01.000.01.03
# │   ├── Volumenstrom > 5.000 bis 10.000 m³/h
# │   │   └── _article
# │   │       → 431.03.01.000.01.04
# │   ├── Volumenstrom > 10.000 bis 20.000 m³/h
# │   │   └── _article
# │   │       → 431.03.01.000.01.05
# │   ├── Volumenstrom > 20.000 bis 30.000 m³/h
# │   │   └── _article
# │   │       → 431.03.01.000.01.06
# │   ├── Volumenstrom > 30.000 bis 50.000 m³/h
# │   │   └── _article
# │   │       → 431.03.01.000.01.07
# │   ├── Volumenstrom > 50.000 bis 75.000 m³/h
# │   │   └── _article
# │   │       → 431.03.01.000.01.08
# │   └── Volumenstrom > 75.000 bis 100.000 m³/h
# │       └── _article
# │           → 431.03.01.000.01.09
# ├── Zu- und Abluftanlagen (mit bis zur einer LBF); ohne WRG
# │   ├── Volumenstrom <= 500 m³/h
# │   │   └── _article
# │   │       → 431.03.01.000.02.01
# │   ├── Volumenstrom > 500 bis 2.500 m³/h
# │   │   └── _article
# │   │       → 431.03.01.000.02.02
# │   ├── Volumenstrom > 2.500 bis 5.000 m³/h
# │   │   └── _article
# │   │       → 431.03.01.000.02.03
# │   ├── Volumenstrom > 5.000 bis 10.000 m³/h
# │   │   └── _article
# │   │       → 431.03.01.000.02.04
# │   ├── Volumenstrom > 10.000 bis 20.000 m³/h
# │   │   └── _article
# │   │       → 431.03.01.000.02.05
# │   ├── Volumenstrom > 20.000 bis 30.000 m³/h
# │   │   └── _article
# │   │       → 431.03.01.000.02.06
# │   ├── Volumenstrom > 30.000 bis 50.000 m³/h
# │   │   └── _article
# │   │       → 431.03.01.000.02.07
# │   ├── Volumenstrom > 50.000 bis 75.000 m³/h
# │   │   └── _article
# │   │       → 431.03.01.000.02.08
# │   └── Volumenstrom > 75.000 bis 100.000 m³/h
# │       └── _article
# │           → 431.03.01.000.02.09
# ├── Zu- und Abluftanlage
# │   └── Frequenzumformer
# │       └── Zubehör
# │           └── _article
# ├── Maschinelle Rauch-/Wärmeabzuganlagen (MRA)
# │   ├── Volumenstrom <= 25.000 m3/h
# │   │   └── _article
# │   │       → 431.04.01.000.00.01
# │   ├── Volumenstrom > 25.000 bis 50.000 m3/h
# │   │   └── _article
# │   │       → 431.04.01.000.00.02
# │   └── Volumenstrom > 50.000 bis 100.000 m3/h
# │       └── _article
# │           → 431.04.01.000.00.03
# ├── Jet-Ventilatoren
# │   ├── Volumenstrom <= 25.000 m3/h
# │   │   └── _article
# │   │       → 431.04.02.000.00.01
# │   ├── Volumenstrom > 25.000 bis 50.000 m3/h
# │   │   └── _article
# │   │       → 431.04.02.000.00.02
# │   └── Volumenstrom > 50.000 bis 100.000 m3/h
# │       └── _article
# │           → 431.04.02.000.00.03
# ├── Rauchschutzdruckanlagen (RDA)
# │   ├── Volumenstrom <= 25.000 m3/h
# │   │   └── _article
# │   │       → 431.04.03.000.00.01
# │   ├── Volumenstrom > 25.000 bis 50.000 m3/h
# │   │   └── _article
# │   │       → 431.04.03.000.00.02
# │   └── Volumenstrom > 50.000 bis 100.000 m3/h
# │       └── _article
# │           → 431.04.03.000.00.03
# ├── Küchenabluftanlagen
# │   ├── Volumenstrom <= 5.000 m3/h
# │   │   └── _article
# │   │       → 431.05.01.000.00.01
# │   ├── Volumenstrom > 5.000 bis 25.000 m3/h
# │   │   └── _article
# │   │       → 431.05.01.000.00.02
# │   └── Volumenstrom > 25.000 bis 50.000 m3/h
# │       └── _article
# │           → 431.05.01.000.00.03
# ├── Küchenabluftanlage
# │   └── Frequenzumformer
# │       └── Zubehör
# │           └── _article
# ├── Luftschleieranlage
# │   ├── Volumenstrom < 2.500 m3/h
# │   │   └── _article
# │   │       → 431.06.01.000.00.01
# │   └── Volumenstrom'> 2.500 bis 5.000 m3/h
# │       └── _article
# │           → 431.06.01.000.00.02
# ├── Teilklimaanlagen
# │   ├── Volumenstrom <= 500 m³/h
# │   │   └── _article
# │   │       → 432.01.01.000.00.01
# │   ├── Volumenstrom > 500 bis 2.500 m³/h
# │   │   └── _article
# │   │       → 432.01.01.000.00.02
# │   ├── Volumenstrom > 2.500 bis 5.000 m³/h
# │   │   └── _article
# │   │       → 432.01.01.000.00.03
# │   ├── Volumenstrom > 5.000 bis 10.000 m³/h
# │   │   └── _article
# │   │       → 432.01.01.000.00.04
# │   ├── Volumenstrom > 10.000 bis 20.000 m³/h
# │   │   └── _article
# │   │       → 432.01.01.000.00.05
# │   ├── Volumenstrom > 20.000 bis 30.000 m³/h
# │   │   └── _article
# │   │       → 432.01.01.000.00.06
# │   ├── Volumenstrom > 30.000 bis 50.000 m³/h
# │   │   └── _article
# │   │       → 432.01.01.000.00.07
# │   ├── Volumenstrom > 50.000 bis 75.000 m³/h
# │   │   └── _article
# │   │       → 432.01.01.000.00.08
# │   └── Volumenstrom > 75.000 bis 100.000 m³/h
# │       └── _article
# │           → 432.01.01.000.00.09
# ├── Teilklimaanlage
# │   └── Frequenzumformer
# │       └── Zubehör
# │           └── _article
# ├── Klimaanlagen
# │   ├── Volumenstrom <= 500 m³/h
# │   │   └── _article
# │   │       → 433.01.01.000.00.01
# │   ├── Volumenstrom > 500 bis 2.500 m³/h
# │   │   └── _article
# │   │       → 433.01.01.000.00.02
# │   ├── Volumenstrom > 2.500 bis 5.000 m³/h
# │   │   └── _article
# │   │       → 433.01.01.000.00.03
# │   ├── Volumenstrom > 5.000 bis 10.000 m³/h
# │   │   └── _article
# │   │       → 433.01.01.000.00.04
# │   ├── Volumenstrom > 10.000 bis 20.000 m³/h
# │   │   └── _article
# │   │       → 433.01.01.000.00.05
# │   ├── Volumenstrom > 20.000 bis 30.000 m³/h
# │   │   └── _article
# │   │       → 433.01.01.000.00.06
# │   ├── Volumenstrom > 30.000 bis 50.000 m³/h
# │   │   └── _article
# │   │       → 433.01.01.000.00.07
# │   ├── Volumenstrom > 50.000 bis 75.000 m³/h
# │   │   └── _article
# │   │       → 433.01.01.000.00.08
# │   └── Volumenstrom > 50.000 bis 100.000 m3/h
# │       └── _article
# │           → 433.01.01.000.00.09
# ├── Klimaanlage
# │   └── Frequenzumformer
# │       └── Zubehör
# │           └── _article
# ├── Splitgeräte
# │   ├── Außeneinheit
# │   │   └── _article
# │   │       → 434.01.01.108.00.03
# │   └── Inneneinheit
# │       └── _article
# │           → 434.01.01.157.00.02
# ├── Kompressionskältemaschine
# │   ├── Kolbenverdichter
# │   │   └── _article
# │   │       → 434.01.02.000.01.04
# │   ├── Schraubenverdichter
# │   │   └── _article
# │   │       → 434.01.02.000.02.04
# │   └── Turboverdichter
# │       └── _article
# │           → 434.01.02.000.03.04
# ├── Absorptionskältemaschine
# │   └── Absorber
# │       └── _article
# │           → 434.01.03.000.01.00
# ├── Umluftkühlgerät
# │   ├── Kälteleistung <= 10 kW
# │   │   └── _article
# │   │       → 434.01.04.000.00.01
# │   ├── Kälteleistung > 10 bis 20 kW
# │   │   └── _article
# │   │       → 434.01.04.000.00.02
# │   └── Kälteleistung > 20 bis 50 kW
# │       └── _article
# │           → 434.01.04.000.00.03
# ├── Klimaschrank
# │   ├── Kälteleistung > 30 bis 80 kW
# │   │   └── _article
# │   │       → 434.01.05.000.00.02
# │   └── Kälteleistung > 80 bis 150 kW
# │       └── _article
# │           → 434.01.05.000.00.03
# ├── Trockenrückkühlanlagen
# │   ├── Rückkühlleistung <= 100 kW
# │   │   └── _article
# │   │       → 434.02.01.000.01.01
# │   ├── Rückkühlleistung > 100 bis 500 kW
# │   │   └── _article
# │   │       → 434.02.01.000.01.02
# │   └── Rückkühlleistung > 500 bis 1.000 kW
# │       └── _article
# │           → 434.02.01.000.01.03
# ├── Verdunstungsrückkühlanlagen (Kühlturme)
# │   ├── Rückkühlleistung <= 100 kW
# │   │   └── _article
# │   │       → 434.02.01.000.02.01
# │   ├── Rückkühlleistung > 100 bis 500 kW
# │   │   └── _article
# │   │       → 434.02.01.000.02.02
# │   └── Rückkühlleistung > 500 bis 1.000 kW
# │       └── _article
# │           → 434.02.01.000.02.03
# ├── Verteiler und Rohrleitungen
# │   ├── Anzahl Kreise 1 bis 5
# │   │   └── _article
# │   │       → 434.03.01.000.01.02
# │   ├── Anzahl Kreise 6 bis 10
# │   │   └── _article
# │   │       → 434.03.01.000.02.02
# │   └── Anzahl Kreise 10 bis 20
# │       └── _article
# │           → 434.03.01.000.03.02
# ├── Verteilnetz / Pumpen
# │   └── Kälteerzeugung
# │       └── _article
# │           → 434.03.01.162.00.00
# ├── Brandschutzklappen
# │   ├── _direct
# │   │   → 439.01.01.053.00.00
# │   └── Küchenabluft (fire safe)
# │       └── _article
# │           → 439.01.01.121.00.00
# ├── Volumenstromregler
# │   └── _direct
# │       → 439.01.01.222.00.00
# ├── Nacherhitzer
# │   └── _direct
# │       → 439.01.01.182.00.00
# ├── Nachkühler
# │   └── _direct
# │       → 439.01.01.183.00.00
# ├── Stützlüfter
# │   └── _direct
# │       → 439.01.01.207.00.00
# ├── Rauchwärmeabzugsanlage (RWA)
# │   ├── elektrisch
# │   │   └── _article
# │   │       → 439.02.01.000.01.00
# │   └── CO2
# │       └── _article
# │           → 439.02.01.000.02.00
# ├── Kühldecke
# │   └── _direct
# │       → 439.03.01.000.00.00
# ├── Kreislaufverbundsystem
# │   ├── Leistung <= 10 kW
# │   │   └── _article
# │   │       → 439.04.01.000.00.01
# │   ├── Leistung > 10 bis 20 kW
# │   │   └── _article
# │   │       → 439.04.01.000.00.02
# │   ├── Leistung > 20 bis 50 kW
# │   │   └── _article
# │   │       → 439.04.01.000.00.03
# │   └── Leistung > 50 bis 100 kW
# │       └── _article
# │           → 439.04.01.000.00.04
# ├── Schaltanlage, Feld exkl. Lasttrennschalter
# │   └── _direct
# │       → 441.01.01.000.00.00
# ├── Lastschalter (Komponente)
# │   ├── Nicht gekapselte (Luftisolierte Schalter, Freiluftschalter)
# │   │   └── _article
# │   │       → 441.01.01.000.01.01
# │   └── Gekapselte (Druckgasschalter / 2
# │       └── _article
# │           → 441.01.01.000.01.02
# ├── Schaltanlage
# │   └── Zulage Stromzähler
# │       └── Zubehör
# │           └── _article
# ├── Trocken-Transformatoren
# │   └── elektrisch
# │       └── _article
# │           → 441.02.01.000.01.02
# ├── Öl-Transformatoren
# │   └── elektrisch
# │       └── _article
# │           → 441.02.01.000.02.02
# ├── Netzersatzanlage-Diesel inkl. Tagestank, inkl. Starter- / Steuerbatterie, inkl. Steuerung
# │   └── elektrisch
# │       └── _article
# │           → 442.01.01.000.00.04
# ├── Blockheizkraftwerk (stromgeführt)
# │   └── _direct
# │       → 442.01.02.000.00.00
# ├── zentrale Batterieanlagen mit/ohne Batteriemanagementsystem
# │   ├── Kapazität <50 Ah
# │   │   └── _article
# │   │       → 442.02.01.000.00.01
# │   ├── Kapazität 50 bis 250 Ah
# │   │   └── _article
# │   │       → 442.02.01.000.00.02
# │   ├── Kapatität 250 bis 500 Ah
# │   │   └── _article
# │   │       → 442.02.01.000.00.03
# │   └── Kapazität 500 bis 1000 Ah
# │       └── _article
# │           → 442.02.01.000.00.04
# ├── USV-Anlage statisch
# │   └── elektrisch
# │       └── _article
# │           → 442.02.02.000.01.05
# ├── USV-Anlage dynamisch
# │   └── _direct
# │       → 442.02.02.000.02.00
# ├── photovoltaische Anlagen (exkl. Wechselrichter)
# │   ├── Kollektorfläche <100 m2
# │   │   └── _article
# │   │       → 442.03.01.000.00.01
# │   ├── Kollektorfläche 100
# │   │   └── _article
# │   │       → 442.03.01.000.00.02
# │   └── Kollektorfläche 500
# │       └── _article
# │           → 442.03.01.000.00.03
# ├── Wechselrichter
# │   └── _direct
# │       → 442.03.01.000.01.00
# ├── Niederspannungshauptverteiler, Feld exkl. Lastschalter
# │   └── _direct
# │       → 443.01.01.000.01.00
# ├── Niederspannungshauptverteiler Anzahl Lasttrennschalter
# │   ├── Nicht gekapselt
# │   │   └── _article
# │   │       → 443.01.01.000.02.01
# │   └── Gekapselt
# │       └── _article
# │           → 443.01.01.000.02.02
# ├── Niederspannungshauptverteiler
# │   └── Zulage Stromzähler
# │       └── Zubehör
# │           └── _article
# ├── Blindstromkompensationsanlagen
# │   └── elektrisch
# │       └── _article
# │           → 443.02.01.000.00.02
# ├── Maximumüberwachungsanlagen
# │   └── _direct
# │       → 443.03.01.000.00.00
# ├── Kabel
# │   └── _direct
# │       → 444.01.01.000.00.00
# ├── Leitungen
# │   └── _direct
# │       → 444.02.01.000.00.00
# ├── Unterverteiler (inkl. Potenzialausgleich)
# │   ├── Stromkreise <20 Stk.
# │   │   └── _article
# │   │       → 444.03.01.000.00.01
# │   ├── Stromkreise 20 bis 50 Stk.
# │   │   └── _article
# │   │       → 444.03.01.000.00.02
# │   └── Stromkreise 50 bis 100 Stk.
# │       └── _article
# │           → 444.03.01.000.00.03
# ├── NS-Unterverteiler
# │   └── Zulage Stromzähler
# │       └── Zubehör
# │           └── _article
# ├── Verlegesysteme
# │   └── _direct
# │       → 444.04.01.000.00.00
# ├── Installationsgeräte
# │   └── _direct
# │       → 444.05.01.000.00.00
# ├── Ortsfeste Leuchten
# │   └── _direct
# │       → 445.01.01.000.00.00
# ├── Sicherheitsbeleuchtungsanlage
# │   ├── Leuchte
# │   │   └── _article
# │   │       → 445.02.01.007.04.00
# │   └── Zentralgerät
# │       └── _article
# │           → 445.02.01.235.00.00
# ├── optische Sicherheitsleitsysteme
# │   ├── Sicherheitszeichen
# │   │   └── _article
# │   │       → 445.02.02.200.02.00
# │   └── Leitmarkierungen
# │       └── _article
# │           → 445.02.02.174.00.00
# ├── Ampelanlage
# │   └── _direct
# │       → 445.03.01.000.00.00
# ├── Äußerere Blitzschutz (inkl. Auffangeinrichtungen, Ableitungen, Erdungen)
# │   └── _direct
# │       → 446.01.01.216.00.00
# ├── Innerer Blitzschutz (Potenzialausgleich)
# │   └── _direct
# │       → 446.01.01.000.00.00
# ├── Ladestation
# │   ├── Ladeart = 1
# │   │   └── _article
# │   │       → 449.01.01.000.01.00
# │   ├── Ladeart = 2
# │   │   └── _article
# │   │       → 449.01.01.000.02.00
# │   ├── Ladeart = 3
# │   │   └── _article
# │   │       → 449.01.01.000.03.00
# │   └── Ladeart = 4
# │       └── _article
# │           → 449.01.01.000.04.00
# ├── Frequenzumformer
# │   └── _direct
# │       → 449.0.01.000.00.00
# ├── Begleitheizung
# │   └── _direct
# │       → 449.03.01.000.00.00
# ├── Taubenabwehranlage (elektrisch)
# │   └── Weidenzaunprinzip
# │       └── _article
# │           → 449.04.01.000.00.00
# ├── TK-Verteiler
# │   └── _direct
# │       → 451.01.01.000.01.00
# ├── Personenrufanlagen
# │   └── Behindertennotruf
# │       └── _article
# │           → 452.01.01.000.00.00
# ├── Lichtruf- und Klingelanlage
# │   └── Anzahl Module (Gesamt)
# │       └── _article
# │           → 452.02.01.000.01.00
# ├── Sprechstellen inkl. Zentraleinheit, Türöffner, Kamera, Monitor
# │   ├── Anzahl Sprechstellen 1 bis 25 Stk.
# │   │   └── _article
# │   │       → 452.03.01.000.01.00
# │   └── Anzahl Sprechstellen 26 bis 50 Stk.
# │       └── _article
# │           → 452.03.01.000.02.00
# ├── Uhrenanlagen
# │   └── _direct
# │       → 453.01.01.000.00.00
# ├── Zeiterfassungsanlagen
# │   └── _direct
# │       → 453.02.01.000.00.00
# ├── Elektroakustische Anlagen
# │   └── Zentraleinheit
# │       └── _article
# │           → 454.01.01.000.00.00
# ├── Lautsprecher
# │   ├── Anzahl Lautsprecher <=100 Stk.
# │   │   └── _article
# │   │       → 454.01.01.000.00.01
# │   ├── Anzahl Lautsprecher > 100 bis 250 Stk.
# │   │   └── _article
# │   │       → 454.01.01.000.00.02
# │   ├── Anzahl Lautsprecher > 250 bis 500 Stk.
# │   │   └── _article
# │   │       → 454.01.01.000.00.03
# │   ├── Anzahl Lautsprecher > 500 bis 750 Stk.
# │   │   └── _article
# │   │       → 454.01.01.000.00.04
# │   └── Anzahl Lautsprecher > 750 bis 1000 Stk.
# │       └── _article
# │           → 454.01.01.000.00.05
# ├── Antennenanlage (Stabantenne, Parabolspiegelantenne)
# │   ├── kraftbetrieben
# │   │   └── _article
# │   │       → 455.01.01.000.00.01
# │   └── nicht kraftbetrieben
# │       └── _article
# │           → 455.01.01.000.00.02
# ├── Verstärker
# │   └── _direct
# │       → 455.01.01.000.01.00
# ├── Verteiler/Dosen
# │   └── _direct
# │       → 455.01.01.000.02.00
# ├── Brandmeldeanlage
# │   └── _direct
# │       → 456.01.01.000.00.00
# ├── Unterzentrale
# │   └── _direct
# │       → 456.01.01.001.01.00
# ├── Signalgeber
# │   ├── optisch
# │   │   └── _article
# │   │       → 456.01.01.202.01.00
# │   └── akustisch
# │       └── _article
# │           → 456.01.01.202.02.00
# ├── Druckknopfmelder
# │   └── _direct
# │       → 456.01.01.132.00.00
# ├── Rauchmelder
# │   ├── Ionisationsrauchmelder
# │   │   └── _article
# │   │       → 456.01.01.189.01.00
# │   ├── optische Rauchmelder
# │   │   └── _article
# │   │       → 456.01.01.189.02.00
# │   ├── Mehrkriterienmelder
# │   │   └── _article
# │   │       → 456.01.01.189.03.00
# │   └── Thermodifferentialmelder
# │       └── _article
# │           → 456.01.01.189.04.00
# ├── Wärmemelder
# │   ├── Mehrkriterienmelder
# │   │   └── _article
# │   │       → 456.01.01.224.01.00
# │   ├── Thermodifferentialmelder
# │   │   └── _article
# │   │       → 456.01.01.224.02.00
# │   └── Linienwärmemelder
# │       └── _article
# │           → 456.01.01.224.03.00
# ├── RAS
# │   └── Anzahl Auswerteeinheiten RAS
# │       └── _article
# │           → 456.01.01.188.01.00
# ├── Überfallmeldeanlage
# │   ├── Zentraleinheit
# │   │   └── _article
# │   │       → 456.02.01.000.00.00
# │   ├── Anzahl Melder
# │   │   └── _article
# │   │       → 456.02.01.000.01.00
# │   └── Anzahl Überfallmeldelinien
# │       └── _article
# │           → 456.02.01.000.02.00
# ├── Einbruchmeldeanlage
# │   ├── Anzahl Auslöser <= 25
# │   │   └── _article
# │   │       → 456.03.01.000.00.01
# │   ├── Anzahl Auslöser 26 bis = 50
# │   │   └── _article
# │   │       → 456.03.01.000.00.02
# │   └── Anzahl Auslöser 51 bis = 100
# │       └── _article
# │           → 456.03.01.000.00.03
# ├── Gas-Warnanlage
# │   ├── Art des Gases = CO
# │   │   └── _article
# │   │       → 456.04.01.000.01.02
# │   ├── Sensoren
# │   │   └── _article
# │   │       → 456.04.01.000.02.00
# │   └── Unterzentralen
# │       └── _article
# │           → 456.04.01.001.00.00
# ├── Leckagewarnanlage
# │   ├── Zentraleinheit
# │   │   └── _article
# │   │       → 456.05.01.000.00.00
# │   └── Sensoren
# │       └── _article
# │           → 456.05.01.000.01.00
# ├── Zugangskontrollanlage
# │   ├── _direct
# │   │   → 456.06.01.000.00.00
# │   ├── Leseeinheiten
# │   │   └── _article
# │   │       → 456.06.01.000.01.00
# │   └── Batterien / Akkus (Transponder, Leseeinheit)
# │       └── _article
# │           → 456.06.01.000.02.00
# ├── Videoüberwachungsanlage
# │   ├── VdS
# │   │   └── _article
# │   │       → 456.07.01.000.03.00
# │   ├── Bewegungsmelder
# │   │   └── _article
# │   │       → 456.07.01.000.04.00
# │   ├── Dämmerungsschalter
# │   │   └── _article
# │   │       → 456.07.01.000.05.00
# │   ├── Innenkamera
# │   │   └── _article
# │   │       → 456.07.01.158.02.00
# │   └── Außenkamera
# │       └── _article
# │           → 456.07.01.109.02.00
# ├── BOS-Anlage
# │   ├── Zentraleinheit
# │   │   └── _article
# │   │       → 457.01.01.000.00.00
# │   └── Funkstellen pro Stück
# │       └── _article
# │           → 457.01.01.000.00.01
# ├── Personenaufzug mit Seil-Antrieb
# │   ├── Anz. Haltestellen 2
# │   │   └── _article
# │   │       → 461.01.01.000.01.01
# │   ├── Anz. Haltestellen 3
# │   │   └── _article
# │   │       → 461.01.01.000.01.02
# │   ├── Anz. Haltestellen 4
# │   │   └── _article
# │   │       → 461.01.01.000.01.03
# │   ├── Anz. Haltestellen 5
# │   │   └── _article
# │   │       → 461.01.01.000.01.04
# │   ├── Anz. Haltestellen 6
# │   │   └── _article
# │   │       → 461.01.01.000.01.05
# │   ├── Anz. Haltestellen 7
# │   │   └── _article
# │   │       → 461.01.01.000.01.06
# │   ├── Anz. Haltestellen 8
# │   │   └── _article
# │   │       → 461.01.01.000.01.07
# │   ├── Anz. Haltestellen 9
# │   │   └── _article
# │   │       → 461.01.01.000.01.08
# │   ├── Anz. Haltestellen 10
# │   │   └── _article
# │   │       → 461.01.01.000.01.09
# │   ├── Anz. Haltestellen 11
# │   │   └── _article
# │   │       → 461.01.01.000.01.10
# │   └── Anz. Haltestellen 12
# │       └── _article
# │           → 461.01.01.000.01.11
# ├── Personenaufzug mit Hydraulik-Antrieb (ohne Ölwechsel)
# │   ├── Anz. Haltestellen 2
# │   │   └── _article
# │   │       → 461.01.01.000.02.01
# │   ├── Anz. Haltestellen 3
# │   │   └── _article
# │   │       → 461.01.01.000.02.02
# │   ├── Anz. Haltestellen 4
# │   │   └── _article
# │   │       → 461.01.01.000.02.03
# │   ├── Anz. Haltestellen 5
# │   │   └── _article
# │   │       → 461.01.01.000.02.04
# │   └── Anz. Haltestellen 6
# │       └── _article
# │           → 461.01.01.000.02.05
# ├── Lastenaufzug mit Seil-Antrieb
# │   ├── Anz. Haltestellen 2
# │   │   └── _article
# │   │       → 461.02.01.000.01.01
# │   ├── Anz. Haltestellen 3
# │   │   └── _article
# │   │       → 461.02.01.000.01.02
# │   ├── Anz. Haltestellen 4
# │   │   └── _article
# │   │       → 461.02.01.000.01.03
# │   ├── Anz. Haltestellen 5
# │   │   └── _article
# │   │       → 461.02.01.000.01.04
# │   ├── Anz. Haltestellen 6
# │   │   └── _article
# │   │       → 461.02.01.000.01.05
# │   ├── Anz. Haltestellen 7
# │   │   └── _article
# │   │       → 461.02.01.000.01.06
# │   ├── Anz. Haltestellen 8
# │   │   └── _article
# │   │       → 461.02.01.000.01.07
# │   ├── Anz. Haltestellen 9
# │   │   └── _article
# │   │       → 461.02.01.000.01.08
# │   ├── Anz. Haltestellen 10
# │   │   └── _article
# │   │       → 461.02.01.000.01.09
# │   ├── Anz. Haltestellen 11
# │   │   └── _article
# │   │       → 461.02.01.000.01.10
# │   └── Anz. Haltestellen 12
# │       └── _article
# │           → 461.02.01.000.01.11
# ├── Lastenaufzug mit Hydraulik-Antrieb (ohne Ölwechsel)
# │   ├── Anz. Haltestellen 2
# │   │   └── _article
# │   │       → 461.02.01.000.02.01
# │   ├── Anz. Haltestellen 3
# │   │   └── _article
# │   │       → 461.02.01.000.02.02
# │   ├── Anz. Haltestellen 4
# │   │   └── _article
# │   │       → 461.02.01.000.02.03
# │   ├── Anz. Haltestellen 5
# │   │   └── _article
# │   │       → 461.02.01.000.02.04
# │   └── Anz. Haltestellen 6
# │       └── _article
# │           → 461.02.01.000.02.05
# ├── Kleingüteraufzug mit Seil-Antrieb
# │   └── _direct
# │       → 461.03.01.000.01.00
# ├── Kleingüteraufzug mit Hydraulik-Antrieb (ohne Ölwechsel)
# │   └── _direct
# │       → 461.03.01.000.02.00
# ├── Treppenlifte
# │   └── _direct
# │       → 461.05.01.000.00.00
# ├── Fahrtreppe, Fahrsteig (ohne brandschutztechnische Reinigung)
# │   ├── Förderlänge <=10 m
# │   │   └── _article
# │   │       → 462.01.01.000.00.01
# │   ├── Förderlange > 10 bis 15 m
# │   │   └── _article
# │   │       → 462.01.01.000.00.02
# │   ├── Förderlange >15 bis 20 m
# │   │   └── _article
# │   │       → 462.01.01.000.00.03
# │   └── Förderlänge > 20 bis 50m
# │       └── _article
# │           → 462.01.01.000.00.04
# ├── Befahranlagen
# │   └── _direct
# │       → 463.01.01.000.00.00
# ├── Brückenkran
# │   ├── Traglast <= 1t
# │   │   └── _article
# │   │       → 465.01.01.000.00.01
# │   ├── Traglast > 1 bis 5t
# │   │   └── _article
# │   │       → 465.01.01.000.00.02
# │   ├── Traglast > 5 bis 20t
# │   │   └── _article
# │   │       → 465.01.01.000.00.03
# │   └── Traglast > 20 bis 50t
# │       └── _article
# │           → 465.01.01.000.00.04
# ├── Deckenkran
# │   ├── Traglast <= 1t
# │   │   └── _article
# │   │       → 465.01.02.000.00.01
# │   ├── Traglast >1 bis 5t
# │   │   └── _article
# │   │       → 465.01.02.000.00.02
# │   └── Traglast > 5 bis 20t
# │       └── _article
# │           → 465.01.02.000.00.03
# ├── Einträgerhängekran
# │   ├── Traglast <= 1t
# │   │   └── _article
# │   │       → 465.01.03.000.00.01
# │   └── Traglast > 1 bis 5t
# │       └── _article
# │           → 465.01.03.000.00.02
# ├── Portalkran
# │   ├── Traglast <= 1t
# │   │   └── _article
# │   │       → 465.01.05.000.00.01
# │   └── Traglast > 1 bis 5t
# │       └── _article
# │           → 465.01.05.000.00.02
# ├── Zweiträgerhängekran
# │   ├── Traglast <=1t
# │   │   └── _article
# │   │       → 465.01.06.000.00.01
# │   └── Traglast > 1 bis 5t
# │       └── _article
# │           → 465.01.06.000.00.02
# ├── Schwenkkran
# │   ├── Traglast <= 1t
# │   │   └── _article
# │   │       → 465.01.07.000.00.01
# │   └── Traglast > 1 bis 5t
# │       └── _article
# │           → 465.01.07.000.00.02
# ├── Hebebühne
# │   └── Förderhöhe <= 3 m
# │       └── _article
# │           → 469.01.01.000.00.01
# ├── Steigleitung mit Einspeisung
# │   ├── trocken
# │   │   └── _article
# │   │       → 474.01.01.000.00.00
# │   └── nass
# │       └── _article
# │           → 474.01.02.000.00.00
# ├── Entnahmestelle'- Entnahmestelle in der Steigleitung
# │   └── _direct
# │       → 474.01.02.176.01.00
# ├── Hydranten
# │   ├── Wandhydranten (trocken oder nass) inkl. Schlauchprüfung
# │   │   └── _article
# │   │       → 474.01.02.176.02.00
# │   ├── Überflurhydrant (ÜHF)
# │   │   └── _article
# │   │       → 474.01.02.156.03.00
# │   └── Unterflurhydrant (UHF)
# │       └── _article
# │           → 474.01.02.156.04.00
# ├── Nasstrockenstation
# │   └── _direct
# │       → 474.01.02.184.00.00
# ├── Druckerhöhungsanlagen
# │   └── _direct
# │       → 474.01.03.000.00.00
# ├── Sprinkleranlagen Vorratstank
# │   └── _direct
# │       → 474.01.04.223.00.00
# ├── Sprinkleranlagen Druckluftwasserkessel
# │   └── inkl. Kompressor und Nachspeisepumpe
# │       └── _article
# │           → 474.01.04.137.00.00
# ├── Sprinklerpumpen
# │   ├── Diesel
# │   │   └── _article
# │   │       → 474.01.04.204.01.00
# │   └── Elektro
# │       └── _article
# │           → 474.01.04.204.02.00
# ├── Nassalarmventilstationen (NAV)
# │   └── _direct
# │       → 474.01.05.000.00.00
# ├── Trockenalarmventilstation (TAV)
# │   └── _direct
# │       → 474.01.06.000.00.00
# ├── Handfeuerlöscher CO2
# │   ├── Inhalt 2 kg
# │   │   └── _article
# │   │       → 474.01.07.000.00.01
# │   ├── Inhalt 5 kg
# │   │   └── _article
# │   │       → 474.01.07.000.00.02
# │   ├── Inhalt 10 kg
# │   │   └── _article
# │   │       → 474.01.07.000.00.03
# │   ├── Inhalt 20 kg
# │   │   └── _article
# │   │       → 474.01.07.000.00.04
# │   ├── Inhalt 30 kg
# │   │   └── _article
# │   │       → 474.01.07.000.00.05
# │   └── Inhalt 60 kg
# │       └── _article
# │           → 474.01.07.000.00.06
# ├── Handfeuerlöscher Pulver
# │   ├── Dauerdrucklöscher
# │   │   └── _article
# │   │       → 474.01.08.000.01.03
# │   └── Aufladelöscher
# │       └── _article
# │           → 474.01.08.000.02.03
# ├── Handfeuerlöscher Wasser
# │   └── Inhalt <= 10 l
# │       └── _article
# │           → 474.01.09.000.00.01
# ├── Handfeuerlöscher Schaum
# │   ├── Dauerdrucklöscher
# │   │   └── _article
# │   │       → 474.01.10.000.01.01
# │   └── Aufladelöscher
# │       └── _article
# │           → 474.01.10.000.02.01
# ├── Handfeuerlöscher Fettbrandlöscher
# │   └── Inhalt <= 10 l
# │       └── _article
# │           → 474.01.11.000.00.01
# ├── Gaslöschanlagen
# │   ├── Argon
# │   │   └── _article
# │   │       → 474.01.12.000.01.03
# │   ├── CO2
# │   │   └── _article
# │   │       → 474.01.12.000.02.03
# │   ├── Stickstoff
# │   │   └── _article
# │   │       → 474.01.12.000.03.03
# │   └── Inergen
# │       └── _article
# │           → 474.01.12.000.04.03
# ├── Küchen-Löschanlagen
# │   └── Ansul
# │       └── _article
# │           → 474.01.12.000.05.00
# ├── Müllpressen und Container
# │   └── kraftbetrieben
# │       └── _article
# │           → 476.01.01.000.01.02
# ├── Papierpresse und Container
# │   └── kraftbetrieben
# │       └── _article
# │           → 476.01.01.000.02.01
# ├── Nassmüllentsorgung
# │   └── _direct
# │       → 476.01.02.000.00.00
# ├── Abfallzerkleinerungsanlage
# │   └── _direct
# │       → 476.01.03.000.00.00
# ├── Sonderabfallentsorgungsanlagen
# │   └── _direct
# │       → 476.01.04.000.00.00
# ├── Recyclinganlagen
# │   └── _direct
# │       → 476.01.05.000.00.00
# ├── Automationsstationen mit Bedien- und Beobachtungseinrichtungen, GA-Funktionen Automationsebene
# │   └── ISP
# │       └── _article
# │           → 481.01.01.000.01.00
# ├── Automationsebene
# │   └── DDC
# │       └── _article
# │           → 481.01.01.128.02.00
# ├── Feldebene
# │   ├── Sensoren
# │   │   └── _article
# │   │       → 481.01.01.142.03.00
# │   └── Aktoren
# │       └── _article
# │           → 481.01.01.142.04.00
# ├── Raumautomationssystem (BUS-System)
# │   ├── zentral
# │   │   └── _article
# │   │       → 481.01.02.000.01.04
# │   └── dezentral
# │       └── _article
# │           → 481.01.02.000.02.04
# └── GA-Schaltschränke
#     └── _direct
#         → 482.01.01.000.01.00
#
# Example usage:
# Available main categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor', 'Rolltore / Rollgittertore', 'Schiebetore (inkl. Feststellanlage)', 'Schnelllauftore', 'Drehflügeltore (Schwenk- und Schwingtore)', 'Sektionaltore', 'Tore', 'Karusselltür (mit Fluchtwegsfunktion); kraftbetrieben', 'Karusselltür (mit Fluchtwegsfunktion); nicht kraftbetrieben', 'Karusselltür (ohne Fluchtwegsfunktion); kraftbetrieben', 'Karusselltür (ohne Fluchtwegsfunktion); nicht kraftbetrieben', 'Schiebetür (mit Fluchtwegsfunktion); kraftbetrieben ohne Brand-/ Rauchschutzfunktion', 'Schiebetür (mit Fluchtwegsfunktion); kraftbetrieben mit Brand-/ Rauchschutzfunktion', 'Schiebetür (mit Fluchtwegsfunktion); nicht kraftbetrieben ohne Brand-/ Rauchschutzfunktion', 'Schiebetür (mit Fluchtwegsfunktion); nicht kraftbetrieben mit Brand-/ Rauchschutzfunktion', 'Schiebetür (ohne Fluchtwegsfunktion); kraftbetrieben ohne Brand-/ Rauchschutzfunktion', 'Schiebetür (ohne Fluchtwegsfunktion); kraftbetrieben mit Brand-/ Rauchschutzfunktion', 'Schiebetür (ohne Fluchtwegsfunktion); nicht kraftbetrieben ohne Brand-/ Rauchschutzfunktion', 'Schiebetür (ohne Fluchtwegsfunktion); nicht kraftbetrieben mit Brand-/ Rauchschutzfunktion', 'Drehflügeltür (mit Fluchtwegsfunktion); kraftbetrieben ohne Brand-/ Rauchschutzfunktion', 'Drehflügeltür (mit Fluchtwegsfunktion); kraftbetrieben mit Brand-/ Rauchschutzfunktion', 'Drehflügeltür (mit Fluchtwegsfunktion); nicht kraftbetrieben ohne Brand-/ Rauchschutzfunktion', 'Drehflügeltür (mit Fluchtwegsfunktion); nicht kraftbetrieben mit Brand-/ Rauchschutzfunktion', 'Drehflügeltür (ohne Fluchtwegsfunktion); kraftbetrieben ohne Brand-/ Rauchschutzfunktion', 'Drehflügeltür (ohne Fluchtwegsfunktion); kraftbetrieben mit Brand-/ Rauchschutzfunktion', 'Drehflügeltür (ohne Fluchtwegsfunktion); nicht kraftbetrieben ohne Brand-/ Rauchschutzfunktion', 'Drehflügeltür (ohne Fluchtwegsfunktion); nicht kraftbetrieben mit Brand-/ Rauchschutzfunktion', 'Türen', 'Personenvereinzelungsanlage, Schleuse/Durchgangsschleuse', 'Rolläden', 'Jalousien', 'Markisen', 'Raffstoreanlage', 'Werbeanlagen', 'Falt- und Schiebewände', 'Lichtkuppeln / Oberlichter / Dachfenster', 'Flachdach', 'Rauchschutz- / Feuerschutzvorhänge / Rauchschürze', 'Tritte / Leitern', 'Sekuranten', 'Anschlagpunkte', 'Seilsysteme', 'Schneelastwaage', 'Abwasserleitung', 'Kontroll-, Reinigungs- und Sammelschächte', 'Bodenrinnen (KGR 400)', 'Bodenrinnen (KGR 500)', 'Bodeneinläufe', 'Straßeneinlaufkästen (KGR 500)', 'Dachrinnen', 'Dacheinläufe', 'Sickerschächte', 'Rigolen', 'Leichtflüssigkeitsabscheider (Benzin/Öl)', 'Fettabscheider', 'Stärkeabscheider', 'Neutralisationsanlage', 'Hebeanlage Einfachpumpe geschlossen', 'Hebeanlage Doppelpumpe geschlossen', 'Tauchpumpe inkl. Pumpensumpf', 'Brunnenanlagen', 'Regenwassernutzungsanlagen', 'Flusswasseranlagen', 'Wasseraufbereitungsanlagen (Enthärtung)', 'Wasseraufbereitungsanlagen (Dosierung)', 'Wasseraufbereitungsanlagen (Umkehrosmose)', 'Enteisenungs-/ Entmanganungsanlagen', 'Druckerhöhungsanlagen (nicht Löschwasser)', 'Wasserverteilung (inkl. Rohrnetz und Absperr-, Entleerungs- und Entnahmearmaturen, Druckminderung)', 'Hygienespüleinrichtungen', 'Wasserfilter', 'Wasserzähler', 'Durchlauferhitzer, Klein-, Wand- und Standspeicher', 'Sanitäre Einrichtungsgegenstände (Waschtisch, Urinale, WC, Duschen, Wannen, etc.)', 'Gastank oberirdisch inkl. Füll- u. Entleerungseinrichtungen', 'Gastank unterirdisch inkl. Füll- u. Entleerungseinrichtungen', 'Gaseinspeisung', 'Gaszähler', 'Gasregelstrecke', 'Heizöltank oberirdisch inkl. Füll- u. Entleerungseinrichtungen', 'Heizöltank unterirdisch inkl. Füll- u. Entleerungseinrichtungen', 'Leckageüberwachungsanlage Heizöltank', 'Heizölversorgungsleitung für Ölbrenner inkl. Armaturen', 'Fernwärmeübergabestation', 'Wasserkessel (ohne Brenner)', 'Dampfkessel', 'Ölbrenner', 'atmosphärische Gasbrenner (ohne Gebläse)', 'Gasgebläsebrenner', 'Brenner für Feststoffe (ausgenommen Einzelraumfeuerungsanlagen)', 'Br ...
#
# Searching for 'Fenster':
#   Path: Fenster mit Kipp- oder Drehflügel -> kraftbetrieben | Article: 334.01.01.000.01.00
#   Path: Fenster mit Kipp- oder Drehflügel -> nicht kraftbetrieben | Article: 334.01.01.000.02.00
#   Path: Hochwasserschutzfenster -> nicht kraftbetrieben | Article: 334.01.02.000.01.00
#   Path: Lichtkuppeln / Oberlichter / Dachfenster -> elektrisch -> Einbauhöhe <= 6 m | Article: 362.01.01.000.01.01
#   Path: Lichtkuppeln / Oberlichter / Dachfenster -> elektrisch -> Einbauhöhe 6 m bis 12 m | Article: 362.01.01.000.01.02
#
# Navigating through tree:
# Options under 'Fenster mit Kipp- oder Drehflügel': ['kraftbetrieben', 'nicht kraftbetrieben']

# %% [markdown]
# ### Customer File (Kundendatei)

# %%
# Basic info
# print(customer_df.info())
# print(customer_df.describe(include='all'))

# Count of buildings
print("Number of unique buildings:", customer_df['WirtEinh'].nunique())

# Top system/eq types
print("Top systems/equipments (EQ-Bezeichnung):")
print(customer_df['EQ-Bezeichnung'].value_counts().head())


# Top equipment classes
print("Top EQ-Klasse-Bezeichnung:")
print(customer_df['EQ-Klasse-Bezeichnung'].value_counts().head())


# Systems/eq per building
systems_per_building = customer_df.groupby('WirtEinh')['Equipment'].nunique()
print("Average systems/equipments per building:", systems_per_building.mean())
# Out:
# Number of unique buildings: 7
# Top systems/equipments (EQ-Bezeichnung):
# Innenbeleuchtung, ortsfest       17
# Abwasserleitungsanlage           15
# Feuerlöscher                     15
# Wasserverteilanlage              13
# Niederspannungsleitungsanlage    10
# Name: EQ-Bezeichnung, dtype: int64
# Top EQ-Klasse-Bezeichnung:
# IZS-Komponenten                   342
# IZS-Zutrittskontrollzentrale       55
# Niederspannungsleitungsanlagen     42
# Lüftungsanlagen                    38
# Kleinlöschgeräte                   28
# Name: EQ-Klasse-Bezeichnung, dtype: int64
# Average systems/equipments per building: 139.0

# %% [markdown]
# ### Sample Objects (Beispielobjekte)

# %%
# print(sample_df.info())
# print(sample_df.describe(include='all'))

# Number of buildings
print("Unique buildings (sample):", sample_df['Gebäude-ID'].nunique())

# Most common systems
print("Top systems (Anlagenname):")
print(sample_df['Anlagenname'].value_counts().head(10))

# Systems per building
systems_per_building_ref = sample_df.groupby('Gebäude-ID')['Anlagenname'].nunique()
print("Average systems per building (sample):", systems_per_building_ref.mean())
# Out:
# Unique buildings (sample): 32
# Top systems (Anlagenname):
# Außentür                         543
# Handfeuerlöscher                 350
# Pumpen                           199
# Stromzähler                      181
# GA-Schaltschränke                140
# NS-Unterverteiler                 86
# Wärmemengenzähler                 78
# Membranausdehnungsgefäß (MAG)     61
# Niederspannungshauptverteiler     54
# Abläufe                           49
# Name: Anlagenname, dtype: int64
# Average systems per building (sample): 151.09375

# %% [markdown]
# ### EP Katalog

# %%
# print(ep_catalog_df.columns)

# %%
# print(ep_catalog_df.info())
# print(ep_catalog_df.describe(include='all'))

# Most common system types (by normalized name)
# print("Top catalog entries:")
# print(ep_catalog_df['Kurztext / Bezeichnung'].value_counts().head(10))

# Count unique catalog items
print("Unique item numbers:", ep_catalog_df['Artikelnummer'].nunique())
# Out:
# Unique item numbers: 614

# %% [markdown]
# #### Grouping Structure of Our Catalogue

# %%
filtered_df = ep_catalog_df[
    (ep_catalog_df['Art'] == 'NG - Normalgruppe') & 
    (ep_catalog_df['Artikelnummer'].fillna('').str.strip() == '')
]
# Select the corresponding values from another column
result = filtered_df['Kurztext / Bezeichnung']

# Show result
print(result)
result.to_csv('result.txt', index=False, header=False)
# Out:
# 0                                 Wartung und Inspektion
# 1      330 - Außenwände - Wände und Stützen, die dem ...
# 2                          334 - Außentüren und -fenster
# 64     338 - Sonnenschutz - Rollläden, Markisen und J...
# 73     339 - Außenwände, sonstiges - Gitter, Geländer...
# 75        340 - Innenwände - Innenwände und Innenstützen
# 76     346 - Elementierte Innenwände - Elementierte W...
# 79            360 - Dächer - Flache oder geneigte Dächer
# 80     362 - Dachfenster, Dachöffnungen - Fenster, Au...
# 83     363 - Dachbeläge - Beläge auf Dachkonstruktion...
# 89            380 - Baukonstruktive Einbauten, sonstiges
# 90     387 - Baukonstruktive Einbauten, sonstiges - z...
# 99     390 - Sonstige Maßnahmen für Baukonstruktionen...
# 100    399 - Sonstige Maßnahmen für Baukonstruktionen...
# 107                 410 - Abwasser-, Wasser-, Gasanlagen
# 108                                411 - Abwasseranlagen
# 142                                  412 - Wasseranlagen
# 174                                     413 - Gasanlagen
# 182    419 - Sonstige Maßnahmen für Abwasser-, Wasser...
# 185                        420 - Wärmeversorgungsanlagen
# 186                         421 - Wärmeerzeugungsanlagen
# 253                              422 - Wärmeverteilnetze
# 277                                423 - Raumheizflächen
# 283             429 - Wärmeversorgungsanlagen, sonstiges
# 286                         430 - Lufttechnische Anlagen
# 287                                431 - Lüftungsanlagen
# 342                               432 - Teilklimaanlagen
# 353                                   433 - Klimaanlagen
# 364                                   434 - Kälteanlagen
# 402              439 - Lufttechnische Anlagen, sonstiges
# 420                              440 - Starkstromanlagen
# 421               441 - Hoch- und Mittelspannungsanlagen
# 431                   442 - Eigenstromversorgungsanlagen
# 455                   443 - Niederspannungsschaltanlagen
# 463            444 - Niederspannungsinstallationsanlagen
# 472                            445 - Beleuchtungsanlagen
# 485                446 - Blitzschutz- und Erdungsanlagen
# 488                   449 - Starkstromanlagen, sonstiges
# 499    450 - Fernmelde- und informationstechnische An...
# 500                      451 - Telekommunikationsanlagen
# 502                        452 - Such- und Signalanlagen
# 507                              453 - Zeitdienstanlagen
# 510                      454 - Elektroakustische Anlagen
# 517                   455 - Fernseh- und Antennenanlagen
# 522                456 - Gefahrenmelde- und Alarmanlagen
# 560                              457 - Übertragungsnetze
# 563                                  460 - Förderanlagen
# 564                                 461 - Aufzugsanlagen
# 600                        462 - Fahrtreppen, Fahrsteige
# 605    463 - Befahranlagen - Fassadenaufzüge und ande...
# 607         465 - Krananlagen - Einschließlich Hebezeuge
# 623                       469 - Förderanlagen, sonstiges
# 625                    470 - Nutzungsspezifische Anlagen
# 626    474 - Feuerlöschanlagen - Sprinkler-, Gaslösch...
# 671    478 - Entsorgungsanlagen - Abfall- und Mediene...
# 679    480 - Gebäudeautomation - Kosten der anlageübe...
# 680                             481 - Automationssysteme
# 693                                 482 - Schaltschränke
# Name: Kurztext / Bezeichnung, dtype: object

# %%
kostengruppe_mapping = {}

for text in result:
    key = text.split(' - ')[0].strip()  # Extract leading number
    kostengruppe_mapping[key] = [text]  # Full text as list

print(kostengruppe_mapping)
# Out:
# {'Wartung und Inspektion': ['Wartung und Inspektion'], '330': ['330 - Außenwände - Wände und Stützen, die dem Außenklima ausgesetzt sind bzw. an das Erdreich oder an andere Bauwerke grenzen'], '334': ['334 - Außentüren und -fenster'], '338': ['338 - Sonnenschutz - Rollläden, Markisen und Jalousien einschließlich Antrieben'], '339': ['339 - Außenwände, sonstiges - Gitter, Geländer, Stoßabweiser und Handläufe'], '340': ['340 - Innenwände - Innenwände und Innenstützen'], '346': ['346 - Elementierte Innenwände - Elementierte Wände, bestehend aus Innenwänden, -türen, -fenstern, -bekleidungen, z.\xa0B. Falt- und Schiebewände, Sanitärtrennwände, Verschläge'], '360': ['360 - Dächer - Flache oder geneigte Dächer'], '362': ['362 - Dachfenster, Dachöffnungen - Fenster, Ausstiege einschließlich Umrahmungen, Beschlägen, Antrieben, Lüftungselementen und sonstigen eingebauten Elementen'], '363': ['363 - Dachbeläge - Beläge auf Dachkonstruktionen einschließlich Schalungen, Lattungen, Gefälle-, Dichtungs-, Dämm-, Schutz- und Nutzschichten; Entwässerungen der Dachfläche bis zum Anschluss an die Abwasseranlagen'], '380': ['380 - Baukonstruktive Einbauten, sonstiges'], '387': ['387 - Baukonstruktive Einbauten, sonstiges - z.\xa0B. Rauchschutzvorhänge'], '390': ['390 - Sonstige Maßnahmen für Baukonstruktionen - Baukonstruktionen und übergreifende Maßnahmen im Zusammenhang mit den Baukonstruktionen'], '399': ['399 - Sonstige Maßnahmen für Baukonstruktionen, sonstiges - Baukonstruktionen, die mehrere Kostengruppen betreffen'], '410': ['410 - Abwasser-, Wasser-, Gasanlagen'], '411': ['411 - Abwasseranlagen'], '412': ['412 - Wasseranlagen'], '413': ['413 - Gasanlagen'], '419': ['419 - Sonstige Maßnahmen für Abwasser-, Wasser-, Gasanlagen, sonstiges'], '420': ['420 - Wärmeversorgungsanlagen'], '421': ['421 - Wärmeerzeugungsanlagen'], '422': ['422 - Wärmeverteilnetze'], '423': ['423 - Raumheizflächen'], '429': ['429 - Wärmeversorgungsanlagen, sonstiges'], '430': ['430 - Lufttechnische Anlagen'], '431': ['431 - Lüftungsanlagen'], '432': ['432 - Teilklimaanlagen'], '433': ['433 - Klimaanlagen'], '434': ['434 - Kälteanlagen'], '439': ['439 - Lufttechnische Anlagen, sonstiges'], '440': ['440 - Starkstromanlagen'], '441': ['441 - Hoch- und Mittelspannungsanlagen'], '442': ['442 - Eigenstromversorgungsanlagen'], '443': ['443 - Niederspannungsschaltanlagen'], '444': ['444 - Niederspannungsinstallationsanlagen'], '445': ['445 - Beleuchtungsanlagen'], '446': ['446 - Blitzschutz- und Erdungsanlagen'], '449': ['449 - Starkstromanlagen, sonstiges'], '450': ['450 - Fernmelde- und informationstechnische Anlagen - Die einzelnen Anlagen enthalten die zugehörigen Verteiler, Kabel, Leitungen.'], '451': ['451 - Telekommunikationsanlagen'], '452': ['452 - Such- und Signalanlagen'], '453': ['453 - Zeitdienstanlagen'], '454': ['454 - Elektroakustische Anlagen'], '455': ['455 - Fernseh- und Antennenanlagen'], '456': ['456 - Gefahrenmelde- und Alarmanlagen'], '457': ['457 - Übertragungsnetze'], '460': ['460 - Förderanlagen'], '461': ['461 - Aufzugsanlagen'], '462': ['462 - Fahrtreppen, Fahrsteige'], '463': ['463 - Befahranlagen - Fassadenaufzüge und andere Befahranlagen'], '465': ['465 - Krananlagen - Einschließlich Hebezeuge'], '469': ['469 - Förderanlagen, sonstiges'], '470': ['470 - Nutzungsspezifische Anlagen'], '474': ['474 - Feuerlöschanlagen - Sprinkler-, Gaslöschanlagen, Löschwasserleitungen, Wandhydranten, Handfeuerlöscher'], '478': ['478 - Entsorgungsanlagen - Abfall- und Medienentsorgungsanlagen, Staubsauganlagen'], '480': ['480 - Gebäudeautomation - Kosten der anlageübergreifenden Automation'], '481': ['481 - Automationssysteme'], '482': ['482 - Schaltschränke']}

# %% [markdown]
# ### Quick Try To See the State of the Problem

# %%
import json
import re
import pandas as pd
from collections import defaultdict

# Kostengruppe mapping - adjust later
kostengruppe_mapping = {
    '334': ['Fensterbänke', 'Fenster', 'Türen'],
    '335': ['Türen', 'Tore'],
    '336': ['Rollläden', 'Jalousien', 'Markisen'],
    '421': ['Abwasseranlagen'],
    '422': ['Wasseranlagen'],
    '431': ['Wärmeversorgungsanlagen'],
    '432': ['Raumlufttechnische Anlagen'],
    '441': ['Starkstromanlagen'],
    '442': ['Fernmelde- und informationstechnische Anlagen'],
    '443': ['Förderanlagen'],
    '444': ['Nutzungsspezifische Anlagen'],
    '445': ['Gebäudeautomation'],
    '446': ['Anlagen der Außenanlagen']
}

class CatalogueDecisionTree:
    def __init__(self, tree_data=None):
        self.tree = tree_data or {}
    
    def load_from_json(self, filename):
        """Load tree structure from JSON file"""
        with open(filename, 'r', encoding='utf-8') as f:
            self.tree = json.load(f)
    
    def get_article_number(self, path):
        """
        Navigate through the decision tree using a list of choices
        
        Args:
            path (list): List of strings representing the path through the tree
        
        Returns:
            str: Article number if found, None otherwise
        """
        current = self.tree
        
        for choice in path:
            if isinstance(current, dict) and choice in current:
                current = current[choice]
            else:
                return None
        
        # Handle special keys for article numbers
        if isinstance(current, str):
            return current
        elif isinstance(current, dict):
            if "_article" in current:
                return current["_article"]
            elif "_direct" in current:
                return current["_direct"]
        
        return None
    
    def get_available_options(self, path=None):
        """
        Get available options at the current level of the tree
        
        Args:
            path (list): Current path in the tree (optional)
        
        Returns:
            list: Available options at the current level
        """
        if path is None:
            return list(self.tree.keys())
        
        current = self.tree
        for choice in path:
            if isinstance(current, dict) and choice in current:
                current = current[choice]
            else:
                return []
        
        if isinstance(current, dict):
            # Filter out special keys that start with underscore
            return [key for key in current.keys() if not key.startswith('_')]
        else:
            return []
    
    def find_article_numbers(self, search_term):
        """
        Search for article numbers containing specific terms
        
        Args:
            search_term (str): Term to search for
        
        Returns:
            list: List of (path, article_number) tuples
        """
        results = []
        
        def search_recursive(node, current_path):
            if isinstance(node, str):
                # This is an article number
                if any(search_term.lower() in part.lower() for part in current_path):
                    results.append((current_path.copy(), node))
            elif isinstance(node, dict):
                for key, value in node.items():
                    if key.startswith('_'):
                        # Handle special keys
                        if key == "_article" or key == "_direct":
                            if any(search_term.lower() in part.lower() for part in current_path):
                                results.append((current_path.copy(), value))
                    else:
                        search_recursive(value, current_path + [key])
        
        search_recursive(self.tree, [])
        return results
    
    def print_tree_structure(self, max_depth=3):
        """Print the tree structure for debugging"""
        def print_recursive(node, depth=0, prefix=""):
            if depth > max_depth:
                return
            
            if isinstance(node, str):
                print(f"{prefix}→ {node}")
            elif isinstance(node, dict):
                for i, (key, value) in enumerate(node.items()):
                    is_last = i == len(node) - 1
                    print(f"{prefix}{'└── ' if is_last else '├── '}{key}")
                    extension = "    " if is_last else "│   "
                    print_recursive(value, depth + 1, prefix + extension)
        
        print_recursive(self.tree)

class CatalogueParser:
    def __init__(self):
        self.tree = defaultdict(dict)
        
    def parse_catalogue_dataframe(self, df, description_col=None, article_col=None):
        """
        Parse the catalogue data from pandas DataFrame
        
        Args:
            df (pd.DataFrame): DataFrame containing catalogue data
            description_col (str): Name of the description column (auto-detected if None)
            article_col (str): Name of the article number column (auto-detected if None)
        
        Returns:
            dict: Hierarchical tree structure
        """
        # Auto-detect column names if not provided
        if description_col is None:
            # Look for common description column names
            desc_candidates = ['Kurztext / Bezeichnung', 'Kurztext', 'Bezeichnung', 'Description', 'Item']
            for col in df.columns:
                if any(candidate.lower() in col.lower() for candidate in desc_candidates):
                    description_col = col
                    break
            if description_col is None:
                description_col = df.columns[0]  # Use first column as fallback
        
        if article_col is None:
            # Look for common article number column names
            article_candidates = ['Artikelnummer', 'Article', 'Number', 'Code', 'ID']
            for col in df.columns:
                if any(candidate.lower() in col.lower() for candidate in article_candidates):
                    article_col = col
                    break
            if article_col is None:
                article_col = df.columns[1] if len(df.columns) > 1 else df.columns[0]
        
        print(f"Using columns: Description='{description_col}', Article='{article_col}'")
        
        # Process each row
        for idx, row in df.iterrows():
            description = str(row[description_col]).strip() if pd.notna(row[description_col]) else ""
            article_number = str(row[article_col]).strip() if pd.notna(row[article_col]) else ""
            
            # Skip empty rows, headers, and rows without article numbers
            if (description and article_number and 
                article_number != 'nan' and 
                not description.startswith('Wartung') and
                not description.lower().startswith('kurztext')):
                
                self.parse_item(description, article_number)
        
        return dict(self.tree)
    
    def parse_catalogue_data(self, data_text):
        """
        Parse the catalogue data from text format (kept for backward compatibility)
        
        Args:
            data_text (str): Raw catalogue data as text
        
        Returns:
            dict: Hierarchical tree structure
        """
        lines = data_text.strip().split('\n')
        
        for line in lines:
            if '\t' in line and line.strip():
                # Split by tab to separate description and article number
                parts = line.strip().split('\t')
                if len(parts) >= 2:
                    description = parts[0].strip()
                    article_number = parts[1].strip() if parts[1].strip() else None
                    
                    # Skip header lines and category headers without article numbers
                    if description and article_number and not description.startswith('Wartung'):
                        self.parse_item(description, article_number)
        
        return dict(self.tree)
    
    def parse_item(self, description, article_number):
        """
        Parse individual item description and create hierarchical structure
        
        Args:
            description (str): Item description
            article_number (str): Article number
        """
        # Remove leading numbers and dashes (e.g., "334 - ")
        cleaned_desc = re.sub(r'^\d+\s*-\s*', '', description).strip()
        
        # Split by " - " to get different levels
        parts = [part.strip() for part in cleaned_desc.split(' - ')]
        
        if not parts:
            return
        
        # First part is usually the main category
        main_category = parts[0]
        
        # Process the rest of the description
        if len(parts) > 1:
            # Join the remaining parts and parse them
            detail_description = ' - '.join(parts[1:])
            hierarchy = self.extract_hierarchy(detail_description)
        else:
            hierarchy = []
        
        # Build the tree structure
        self.build_tree_path(main_category, hierarchy, article_number)
    
    def extract_hierarchy(self, description):
        """
        Extract hierarchical information from item description
        
        Args:
            description (str): Detailed description
        
        Returns:
            list: List of hierarchical levels
        """
        hierarchy = []
        
        # Common patterns to identify different levels
        patterns = {
            'type': r'^([^-;]+?)(?:\s*-\s*|\s*;\s*|$)',
            'power': r'(kraftbetrieben|nicht kraftbetrieben|elektrisch|mechanisch)',
            'function': r'(mit|ohne)\s+(Brand-?/?Rauchschutzfunktion|Fluchtwegsfunktion|Brandschutzfunktion)',
            'wings': r'(\d+-flüglig)',
            'size': r'(Breite\s*[<>]\s*\d+\s*m[^;]*|Höhe\s*[<>]\s*\d+\s*m[^;]*|Einbauhöhe[^;]*|Innendurchmesser[^;]*|Dachfläche[^;]*)',
        }
        
        # Extract main type/category
        type_match = re.search(patterns['type'], description)
        if type_match:
            main_type = type_match.group(1).strip()
            if main_type and not any(x in main_type.lower() for x in ['kraftbetrieben', 'elektrisch', 'mechanisch']):
                hierarchy.append(('type', main_type))
        
        # Extract power/operation method
        power_match = re.search(patterns['power'], description)
        if power_match:
            hierarchy.append(('power', power_match.group(1)))
        
        # Extract function (Brand/Rauch/Fluchtweg)
        function_match = re.search(patterns['function'], description)
        if function_match:
            function_desc = f"{function_match.group(1)} {function_match.group(2)}"
            hierarchy.append(('function', function_desc))
        
        # Extract wings information
        wings_match = re.search(patterns['wings'], description)
        if wings_match:
            hierarchy.append(('wings', wings_match.group(1)))
        
        # Extract size information
        size_match = re.search(patterns['size'], description)
        if size_match:
            hierarchy.append(('size', size_match.group(1).strip()))
        
        # Handle special cases
        if 'Zulage' in description:
            hierarchy.append(('type', 'Zubehör'))
            if 'Feststellanlage' in description:
                hierarchy.append(('subtype', 'Feststellanlage für Brand-/Rauchschutzfunktion'))
            elif 'Motorschloss' in description:
                hierarchy.append(('subtype', 'Motorschloss'))
            elif 'Flichttürterminal' in description:
                hierarchy.append(('subtype', 'Flichttürterminal'))
            elif 'Fluchtürwächter' in description:
                hierarchy.append(('subtype', 'Fluchtürwächter'))
        
        return hierarchy
    
    def build_tree_path(self, main_category, hierarchy, article_number):
        """
        Build the tree path from main category through hierarchy to article number
        
        Args:
            main_category (str): Main category
            hierarchy (list): List of (type, value) tuples
            article_number (str): Final article number
        """
        # Ensure main category exists as a dict
        if main_category not in self.tree:
            self.tree[main_category] = {}
        elif not isinstance(self.tree[main_category], dict):
            self.tree[main_category] = {}
        
        current = self.tree[main_category]
        
        # Group hierarchy items by logical structure
        type_items = [item[1] for item in hierarchy if item[0] == 'type']
        power_items = [item[1] for item in hierarchy if item[0] == 'power']
        function_items = [item[1] for item in hierarchy if item[0] == 'function']
        wings_items = [item[1] for item in hierarchy if item[0] == 'wings']
        size_items = [item[1] for item in hierarchy if item[0] == 'size']
        subtype_items = [item[1] for item in hierarchy if item[0] == 'subtype']
        
        # Build path: type -> power -> function -> wings -> size
        path_elements = type_items + power_items + function_items + wings_items + size_items + subtype_items
        
        # Navigate/create the path
        for i, element in enumerate(path_elements):
            if element not in current:
                current[element] = {}
            elif not isinstance(current[element], dict):
                # If we hit a leaf node (string), we need to restructure
                # Save the existing value and convert to dict
                existing_value = current[element]
                current[element] = {"_direct": existing_value}
            current = current[element]
        
        # Set the article number at the end
        if path_elements:
            # Navigate back to set the final value
            target = self.tree[main_category]
            for element in path_elements[:-1]:
                target = target[element]
            
            # Check if the final element already exists
            final_element = path_elements[-1]
            if final_element in target and isinstance(target[final_element], dict):
                # If it's a dict, add the article number as a special key
                target[final_element]["_article"] = article_number
            else:
                # Direct assignment
                target[final_element] = article_number
        else:
            # Direct assignment to main category - but main category should be a dict
            # Store the article number with a special key
            if isinstance(self.tree[main_category], dict):
                self.tree[main_category]["_direct"] = article_number
            else:
                self.tree[main_category] = article_number
    
    def save_to_json(self, filename, tree_data):
        """Save the tree structure to a JSON file"""
        with open(filename, 'w', encoding='utf-8') as f:
            json.dump(tree_data, f, indent=2, ensure_ascii=False)
    
    def load_from_file(self, filename):
        """Load catalogue data from file"""
        with open(filename, 'r', encoding='utf-8') as f:
            return f.read()

class CustomerEquipmentMatcher:
    def __init__(self, decision_tree):
        self.decision_tree = decision_tree
        
        # Comprehensive mapping from customer Kostengruppe to catalogue categories
        
        self.kostengruppe_mapping = kostengruppe_mapping
    
    def extract_kostengruppe(self, merkmal):
        """Extract Kostengruppe from EQ-Merkmal text"""
        if pd.isnull(merkmal):
            return None
        match = re.search(r'Kostengruppe DIN 276-1:\s*(\d{3})', str(merkmal))
        if match:
            return match.group(1)
        return None
    
    def search_kostengruppe_in_all(self, row):
        """Search for Kostengruppe in all EQ-Merkmal columns"""
        for col in row.index:
            if 'EQ-Merkmal' in col:
                match = self.extract_kostengruppe(row[col])
                if match:
                    return match
        return None
    
    def extract_equipment_characteristics(self, row):
        """Extract relevant characteristics from equipment data"""
        characteristics = {
            'bezeichnung': str(row.get('EQ-Bezeichnung', '')).lower(),
            'klasse': str(row.get('EQ-Klasse-Bezeichnung', '')).lower(),
            'gewerk': str(row.get('Gewerk', '')).lower(),
            'anlagenauspragung': str(row.get('Anlagenausprägung', '')).lower(),
        }
        
        # Extract characteristics from EQ-Merkmal columns
        merkmal_data = {}
        for col in row.index:
            if 'EQ-Merkmal' in col and pd.notna(row[col]):
                merkmal_text = str(row[col]).lower()
                
                # Look for power/operation characteristics
                if any(keyword in merkmal_text for keyword in ['kraftbetrieben', 'elektrisch', 'mechanisch']):
                    if 'kraftbetrieben' in merkmal_text:
                        merkmal_data['power'] = 'kraftbetrieben'
                    elif 'elektrisch' in merkmal_text:
                        merkmal_data['power'] = 'elektrisch'
                    elif 'mechanisch' in merkmal_text:
                        merkmal_data['power'] = 'mechanisch'
                
                # Look for safety functions
                if any(keyword in merkmal_text for keyword in ['brand', 'rauch', 'flucht']):
                    if 'brand' in merkmal_text or 'rauch' in merkmal_text:
                        merkmal_data['safety'] = 'mit brand-/rauchschutzfunktion'
                    elif 'flucht' in merkmal_text:
                        merkmal_data['safety'] = 'mit fluchtwegsfunktion'
                
                # Look for size information
                if any(keyword in merkmal_text for keyword in ['breite', 'höhe', 'durchmesser', 'fläche']):
                    merkmal_data['size_info'] = merkmal_text
        
        characteristics.update(merkmal_data)
        return characteristics
    
    def find_best_match(self, kostengruppe, characteristics):
        """
        Find the best matching article number for given characteristics
        
        Args:
            kostengruppe (str): Customer equipment Kostengruppe
            characteristics (dict): Equipment characteristics
        
        Returns:
            tuple: (article_number, score) or (None, 0) if no match found
        """
        # Use the enhanced fuzzy matching
        article_number, score, path = self.find_best_match_fuzzy(kostengruppe, characteristics)
        return article_number, score
    
    def analyze_catalogue_structure(self):
        """Analyze and print the catalogue structure to help with mapping"""
        print("\n=== CATALOGUE STRUCTURE ANALYSIS ===")
        print("Available categories in catalogue:")
        
        for category, content in self.decision_tree.tree.items():
            print(f"\n📁 {category}")
            if isinstance(content, dict):
                self._print_subcategories(content, indent="  ")
            else:
                print(f"  → {content}")
    
    def _print_subcategories(self, node, indent="", max_depth=2, current_depth=0):
        """Helper to print subcategories with limited depth"""
        if current_depth >= max_depth:
            return
            
        for key, value in list(node.items())[:5]:  # Limit to first 5 items
            if key.startswith('_'):
                if key in ['_article', '_direct']:
                    print(f"{indent}→ Article: {value}")
            else:
                print(f"{indent}├── {key}")
                if isinstance(value, dict):
                    self._print_subcategories(value, indent + "│   ", max_depth, current_depth + 1)
                else:
                    print(f"{indent}│   → {value}")
        
        if len(node) > 5:
            print(f"{indent}... and {len(node) - 5} more items")
    
    def find_best_match_fuzzy(self, kostengruppe, characteristics):
        """Enhanced matching with fuzzy search across all categories"""
        
        best_match = None
        highest_score = 0
        best_path = []
        
        # If no direct mapping, search all categories
        possible_categories = self.kostengruppe_mapping.get(kostengruppe, [])
        if not possible_categories:
            possible_categories = list(self.decision_tree.tree.keys())
        
        print(f"  Searching in categories: {possible_categories[:3]}{'...' if len(possible_categories) > 3 else ''}")
        
        for category in possible_categories:
            if category in self.decision_tree.tree:
                matches = self._search_category_for_matches_enhanced(category, characteristics)
                for match, score, path in matches:
                    if score > highest_score:
                        highest_score = score
                        best_match = match
                        best_path = path
        
        return best_match, highest_score, best_path
    
    def _search_category_for_matches_enhanced(self, category, characteristics):
        """Enhanced search with better scoring"""
        matches = []
        category_tree = self.decision_tree.tree[category]
        
        def search_recursive(node, path, score):
            if isinstance(node, str):
                # Found an article number
                matches.append((node, score, path.copy()))
            elif isinstance(node, dict):
                for key, value in node.items():
                    if key.startswith('_'):
                        # Handle special keys
                        if key in ["_article", "_direct"]:
                            matches.append((value, score, path.copy()))
                    else:
                        # Calculate score based on keyword matching
                        key_lower = key.lower()
                        new_score = score
                        
                        # Equipment type matching (high priority)
                        equipment_types = ['fenster', 'tür', 'tor', 'rolladen', 'jalousie', 'markise', 
                                         'lüftung', 'heizung', 'pumpe', 'beleuchtung', 'schalter']
                        for eq_type in equipment_types:
                            if eq_type in characteristics['bezeichnung'] and eq_type in key_lower:
                                new_score += 30
                        
                        # Power/operation method matching
                        if 'power' in characteristics:
                            power_keywords = ['kraftbetrieben', 'elektrisch', 'mechanisch', 'automatisch']
                            if any(pw in key_lower for pw in power_keywords):
                                if characteristics['power'] in key_lower:
                                    new_score += 25
                                else:
                                    new_score += 10  # Partial match
                        
                        # Safety function matching  
                        if 'safety' in characteristics:
                            safety_keywords = ['brand', 'rauch', 'flucht', 'sicherheit']
                            if any(sw in key_lower for sw in safety_keywords):
                                new_score += 20
                        
                        # Generic keyword matching
                        bezeichnung_words = characteristics['bezeichnung'].split()
                        key_words = key_lower.split()
                        common_words = set(bezeichnung_words) & set(key_words)
                        new_score += len(common_words) * 5
                        
                        # Continue search
                        search_recursive(value, path + [key], new_score)
        
        search_recursive(category_tree, [category], 0)
        return matches
    
    def _search_category_for_matches(self, category, characteristics):
        """Search within a category for matching items"""
        matches = []
        category_tree = self.decision_tree.tree[category]
        
        def search_recursive(node, path, score):
            if isinstance(node, str):
                # Found an article number
                matches.append((node, score))
            elif isinstance(node, dict):
                for key, value in node.items():
                    if key.startswith('_'):
                        # Handle special keys
                        if key in ["_article", "_direct"]:
                            matches.append((value, score))
                    else:
                        # Calculate score based on keyword matching
                        key_lower = key.lower()
                        new_score = score
                        
                        # Check for keyword matches
                        if any(char in characteristics['bezeichnung'] for char in key_lower.split()):
                            new_score += 10
                        
                        if 'power' in characteristics and characteristics['power'] in key_lower:
                            new_score += 20
                        
                        if 'safety' in characteristics and any(safety_word in key_lower for safety_word in characteristics['safety'].split()):
                            new_score += 15
                        
                        # Check for equipment type matches
                        equipment_keywords = ['fenster', 'tür', 'tor', 'rolladen', 'jalousie', 'markise']
                        for keyword in equipment_keywords:
                            if keyword in characteristics['bezeichnung'] and keyword in key_lower:
                                new_score += 25
                        
                        search_recursive(value, path + [key], new_score)
        
        search_recursive(category_tree, [category], 0)
        return matches
    
    def assign_article_numbers(self, customer_df):
        """Assign article numbers to customer equipment data"""
        
        # First extract Kostengruppe for all rows
        customer_df['Extracted_Kostengruppe'] = customer_df.apply(self.search_kostengruppe_in_all, axis=1)
        
        # Initialize columns for results
        customer_df['Artikelnummer_Assigned'] = None
        customer_df['Match_Score'] = 0
        customer_df['Match_Category'] = None
        customer_df['Match_Path'] = None
        
        successful_matches = 0
        total_rows = len(customer_df)
        
        print(f"Processing {total_rows} equipment records...")
        
        for idx, row in customer_df.iterrows():
            kostengruppe = row['Extracted_Kostengruppe']
            
            if kostengruppe:
                # Extract equipment characteristics
                characteristics = self.extract_equipment_characteristics(row)
                
                # Find best match
                article_number, score = self.find_best_match(kostengruppe, characteristics)
                
                if article_number:
                    customer_df.at[idx, 'Artikelnummer_Assigned'] = article_number
                    customer_df.at[idx, 'Match_Score'] = score
                    customer_df.at[idx, 'Match_Category'] = kostengruppe
                    successful_matches += 1
                    
                    if idx % 100 == 0:  # Progress indicator
                        print(f"Processed {idx}/{total_rows} rows...")
        
        print(f"\nMatching complete!")
        print(f"Successfully matched: {successful_matches}/{total_rows} ({successful_matches/total_rows*100:.1f}%)")
        
        return customer_df
    
    def get_matching_summary(self, customer_df):
        """Get summary of matching results"""
        if 'Artikelnummer_Assigned' not in customer_df.columns:
            print("No matching results found. Run assign_article_numbers first.")
            return
        
        total = len(customer_df)
        matched = customer_df['Artikelnummer_Assigned'].notna().sum()
        unmatched = total - matched
        
        print(f"\n=== MATCHING SUMMARY ===")
        print(f"Total equipment records: {total}")
        print(f"Successfully matched: {matched} ({matched/total*100:.1f}%)")
        print(f"Unmatched: {unmatched} ({unmatched/total*100:.1f}%)")
        
        # Show matches by Kostengruppe
        if matched > 0:
            print(f"\nMatches by Kostengruppe:")
            kostengruppe_summary = customer_df[customer_df['Artikelnummer_Assigned'].notna()]['Extracted_Kostengruppe'].value_counts()
            for kg, count in kostengruppe_summary.items():
                print(f"  {kg}: {count} matches")
        
        # Show some examples
        if matched > 0:
            print(f"\nExample matches:")
            examples = customer_df[customer_df['Artikelnummer_Assigned'].notna()][
                ['EQ-Bezeichnung', 'Extracted_Kostengruppe', 'Artikelnummer_Assigned', 'Match_Score']
            ].head(5)
            print(examples.to_string(index=False))
        
        # Show unmatched items with Kostengruppe
        if unmatched > 0:
            print(f"\nUnmatched items by Kostengruppe:")
            unmatched_kg = customer_df[customer_df['Artikelnummer_Assigned'].isna()]['Extracted_Kostengruppe'].value_counts()
            for kg, count in unmatched_kg.items():
                print(f"  {kg}: {count} unmatched")

# Example usage for customer matching
def match_customer_equipment(catalogue_file_path, customer_df):
    """
    Complete workflow to match customer equipment with catalogue
    
    Args:
        catalogue_file_path (str): Path to catalogue Excel file
        customer_df (pd.DataFrame): Customer equipment DataFrame
    
    Returns:
        pd.DataFrame: Customer DataFrame with assigned article numbers
    """
    
    # Step 1: Load and parse catalogue
    print("Step 1: Loading catalogue...")
    try:
        catalogue_df = pd.read_excel(catalogue_file_path)
        parser = CatalogueParser()
        tree_data = parser.parse_catalogue_dataframe(catalogue_df)
        
        # Create decision tree
        decision_tree = CatalogueDecisionTree(tree_data)
        print("Catalogue loaded and parsed successfully!")
        
    except Exception as e:
        print(f"Error loading catalogue: {e}")
        return customer_df
    
    # Step 2: Create matcher and assign article numbers
    print("\nStep 2: Matching customer equipment...")
    matcher = CustomerEquipmentMatcher(decision_tree)
    result_df = matcher.assign_article_numbers(customer_df.copy())
    
    # Step 3: Show summary
    matcher.get_matching_summary(result_df)
    
    return result_df

# Example usage and testing
if __name__ == "__main__":
    
    # Method 1: Complete customer equipment matching workflow
    print("=== CUSTOMER EQUIPMENT MATCHING ===")
    
    catalogue_file_path = 'EP_Katalog.xlsx' 
    
    # If you have customer_df already loaded:
    # result_df = match_customer_equipment(catalogue_file_path, customer_df)
    
    # Or load customer data from Excel:
    customer_df = pd.read_excel('Kundendatei.xlsx')
    result_df = match_customer_equipment(catalogue_file_path, customer_df)
# Out:
# === CUSTOMER EQUIPMENT MATCHING ===
# Step 1: Loading catalogue...
# Using columns: Description='Kurztext / Bezeichnung', Article='Artikelnummer'
# Catalogue loaded and parsed successfully!
#
# Step 2: Matching customer equipment...
# Processing 973 equipment records...
#   Searching in categories: ['Wärmeversorgungsanlagen']
#   Searching in categories: ['Wärmeversorgungsanlagen']
#   Searching in categories: ['Wärmeversorgungsanlagen']
#   Searching in categories: ['Anlagen der Außenanlagen']
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Nutzungsspezifische Anlagen']
#   Searching in categories: ['Gebäudeautomation']
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Nutzungsspezifische Anlagen']
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Nutzungsspezifische Anlagen']
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Anlagen der Außenanlagen']
#   Searching in categories: ['Anlagen der Außenanlagen']
#   Searching in categories: ['Gebäudeautomation']
#   Searching in categories: ['Gebäudeautomation']
#   Searching in categories: ['Gebäudeautomation']
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Gebäudeautomation']
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Abwasseranlagen']
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Gebäudeautomation']
#   Searching in categories: ['Nutzungsspezifische Anlagen']
#   Searching in categories: ['Anlagen der Außenanlagen']
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Wärmeversorgungsanlagen']
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Gebäudeautomation']
#   Searching in categories: ['Gebäudeautomation']
#   Searching in categories: ['Gebäudeautomation']
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Anlagen der Außenanlagen']
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Anlagen der Außenanlagen']
#   Searching in categories: ['Nutzungsspezifische Anlagen']
#   Searching in categories: ['Gebäudeautomation']
#   Searching in categories: ['Abwasseranlagen']
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Anlagen der Außenanlagen']
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Nutzungsspezifische Anlagen']
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Gebäudeautomation']
#   Searching in categories: ['Wärmeversorgungsanlagen']
#   Searching in categories: ['Wärmeversorgungsanlagen']
#   Searching in categories: ['Raumlufttechnische Anlagen']
#   Searching in categories: ['Wärmeversorgungsanlagen']
#   Searching in categories: ['Wärmeversorgungsanlagen']
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Wärmeversorgungsanlagen']
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Wärmeversorgungsanlagen']
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Wärmeversorgungsanlagen']
#   Searching in categories: ['Wärmeversorgungsanlagen']
#   Searching in categories: ['Wärmeversorgungsanlagen']
#   Searching in categories: ['Wärmeversorgungsanlagen']
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Wärmeversorgungsanlagen']
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
# Processed 100/973 rows...
#   Searching in categories: ['Abwasseranlagen']
#   Searching in categories: ['Abwasseranlagen']
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Anlagen der Außenanlagen']
#   Searching in categories: ['Anlagen der Außenanlagen']
#   Searching in categories: ['Anlagen der Außenanlagen']
#   Searching in categories: ['Anlagen der Außenanlagen']
#   Searching in categories: ['Anlagen der Außenanlagen']
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Abwasseranlagen']
#   Searching in categories: ['Abwasseranlagen']
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Abwasseranlagen']
#   Searching in categories: ['Abwasseranlagen']
#   Searching in categories: ['Gebäudeautomation']
#   Searching in categories: ['Gebäudeautomation']
#   Searching in categories: ['Gebäudeautomation']
#   Searching in categories: ['Gebäudeautomation']
#   Searching in categories: ['Gebäudeautomation']
#   Searching in categories: ['Gebäudeautomation']
#   Searching in categories: ['Gebäudeautomation']
#   Searching in categories: ['Gebäudeautomation']
#   Searching in categories: ['Gebäudeautomation']
#   Searching in categories: ['Gebäudeautomation']
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Wärmeversorgungsanlagen']
#   Searching in categories: ['Nutzungsspezifische Anlagen']
#   Searching in categories: ['Nutzungsspezifische Anlagen']
#   Searching in categories: ['Nutzungsspezifische Anlagen']
#   Searching in categories: ['Nutzungsspezifische Anlagen']
#   Searching in categories: ['Nutzungsspezifische Anlagen']
#   Searching in categories: ['Nutzungsspezifische Anlagen']
#   Searching in categories: ['Nutzungsspezifische Anlagen']
#   Searching in categories: ['Nutzungsspezifische Anlagen']
#   Searching in categories: ['Nutzungsspezifische Anlagen']
#   Searching in categories: ['Nutzungsspezifische Anlagen']
#   Searching in categories: ['Nutzungsspezifische Anlagen']
#   Searching in categories: ['Nutzungsspezifische Anlagen']
#   Searching in categories: ['Nutzungsspezifische Anlagen']
#   Searching in categories: ['Nutzungsspezifische Anlagen']
#   Searching in categories: ['Nutzungsspezifische Anlagen']
#   Searching in categories: ['Nutzungsspezifische Anlagen']
#   Searching in categories: ['Nutzungsspezifische Anlagen']
#   Searching in categories: ['Nutzungsspezifische Anlagen']
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Gebäudeautomation']
#   Searching in categories: ['Gebäudeautomation']
#   Searching in categories: ['Gebäudeautomation']
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Raumlufttechnische Anlagen']
#   Searching in categories: ['Wärmeversorgungsanlagen']
#   Searching in categories: ['Wärmeversorgungsanlagen']
#   Searching in categories: ['Wärmeversorgungsanlagen']
#   Searching in categories: ['Wärmeversorgungsanlagen']
#   Searching in categories: ['Wärmeversorgungsanlagen']
#   Searching in categories: ['Wärmeversorgungsanlagen']
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Gebäudeautomation']
#   Searching in categories: ['Gebäudeautomation']
#   Searching in categories: ['Gebäudeautomation']
#   Searching in categories: ['Gebäudeautomation']
#   Searching in categories: ['Gebäudeautomation']
#   Searching in categories: ['Gebäudeautomation']
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Nutzungsspezifische Anlagen']
#   Searching in categories: ['Nutzungsspezifische Anlagen']
#   Searching in categories: ['Nutzungsspezifische Anlagen']
#   Searching in categories: ['Nutzungsspezifische Anlagen']
#   Searching in categories: ['Nutzungsspezifische Anlagen']
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Gebäudeautomation']
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Nutzungsspezifische Anlagen']
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Wärmeversorgungsanlagen']
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Wärmeversorgungsanlagen']
#   Searching in categories: ['Wärmeversorgungsanlagen']
#   Searching in categories: ['Wärmeversorgungsanlagen']
#   Searching in categories: ['Wärmeversorgungsanlagen']
#   Searching in categories: ['Wärmeversorgungsanlagen']
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Gebäudeautomation']
#   Searching in categories: ['Gebäudeautomation']
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Wärmeversorgungsanlagen']
#   Searching in categories: ['Wärmeversorgungsanlagen']
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Nutzungsspezifische Anlagen']
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Nutzungsspezifische Anlagen']
#   Searching in categories: ['Gebäudeautomation']
#   Searching in categories: ['Nutzungsspezifische Anlagen']
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Anlagen der Außenanlagen']
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Gebäudeautomation']
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Nutzungsspezifische Anlagen']
#   Searching in categories: ['Nutzungsspezifische Anlagen']
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Abwasseranlagen']
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Wärmeversorgungsanlagen']
#   Searching in categories: ['Wärmeversorgungsanlagen']
#   Searching in categories: ['Wärmeversorgungsanlagen']
#   Searching in categories: ['Fernmelde- und informationstechnische Anlagen']
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Gebäudeautomation']
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Wärmeversorgungsanlagen']
#   Searching in categories: ['Gebäudeautomation']
#   Searching in categories: ['Gebäudeautomation']
#   Searching in categories: ['Gebäudeautomation']
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Gebäudeautomation']
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Nutzungsspezifische Anlagen']
#   Searching in categories: ['Gebäudeautomation']
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Gebäudeautomation']
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
# ...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Gebäudeautomation']
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Wärmeversorgungsanlagen']
#   Searching in categories: ['Wärmeversorgungsanlagen']
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Wärmeversorgungsanlagen']
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Nutzungsspezifische Anlagen']
#   Searching in categories: ['Nutzungsspezifische Anlagen']
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Wärmeversorgungsanlagen']
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Abwasseranlagen']
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Abwasseranlagen']
#   Searching in categories: ['Abwasseranlagen']
#   Searching in categories: ['Abwasseranlagen']
#   Searching in categories: ['Abwasseranlagen']
#   Searching in categories: ['Abwasseranlagen']
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Wärmeversorgungsanlagen']
#   Searching in categories: ['Wärmeversorgungsanlagen']
#   Searching in categories: ['Wärmeversorgungsanlagen']
#   Searching in categories: ['Gebäudeautomation']
#   Searching in categories: ['Gebäudeautomation']
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Wärmeversorgungsanlagen']
#   Searching in categories: ['Wärmeversorgungsanlagen']
#   Searching in categories: ['Wärmeversorgungsanlagen']
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Abwasseranlagen']
#   Searching in categories: ['Abwasseranlagen']
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#   Searching in categories: ['Fenster mit Kipp- oder Drehflügel', 'Hochwasserschutzfenster', 'Falttor']...
#
# Matching complete!
# Successfully matched: 92/973 (9.5%)
#
# === MATCHING SUMMARY ===
# Total equipment records: 973
# Successfully matched: 92 (9.5%)
# Unmatched: 881 (90.5%)
#
# Matches by Kostengruppe:
#   344: 24 matches
#   456: 21 matches
#   411: 12 matches
#   439: 11 matches
#   452: 5 matches
#   413: 4 matches
#   412: 3 matches
#   362: 3 matches
#   475: 3 matches
#   454: 2 matches
#   435: 2 matches
#   469: 1 matches
#   482: 1 matches
#
# Example matches:
#                           EQ-Bezeichnung Extracted_Kostengruppe Artikelnummer_Assigned  Match_Score
#        WTA Entwässerungspumpen, ortsfest                    411    474.01.04.137.00.00           30
#                        Türklingelanlagen                    452    334.03.01.024.00.00           60
# Tür_L001_x_x_x_Haupteingang_Oepfe17331_1                    456    334.03.01.024.00.00           60
#          3 Entwässerungspumpen, ortsfest                    411    474.01.04.137.00.00           30
#         Türcodeanlage u. Türsprechanlage                    452    334.03.01.024.00.00           60
#
# Unmatched items by Kostengruppe:
#   456: 388 unmatched
#   431: 64 unmatched
#   445: 61 unmatched
#   411: 45 unmatched
#   444: 42 unmatched
#   412: 40 unmatched
#   471: 31 unmatched
#   475: 31 unmatched
#   421: 18 unmatched
#   369: 15 unmatched
#   446: 14 unmatched
#   419: 10 unmatched
#   461: 10 unmatched
#   454: 9 unmatched
#   439: 8 unmatched
#   362: 7 unmatched
#   465: 6 unmatched
#   334: 4 unmatched
#   474: 4 unmatched
#   432: 3 unmatched
#   453: 2 unmatched
#   482: 2 unmatched
#   435: 2 unmatched
#   463: 1 unmatched
#   455: 1 unmatched
#   442: 1 unmatched
#   359: 1 unmatched
#   452: 1 unmatched

# %%
print(result_df['Artikelnummer_Assigned'].unique())
# Out:
# [None '474.01.04.137.00.00' '334.03.01.024.00.00' '334.03.01.000.05.01'
#  '334.03.01.000.05.02' '389.01.01.000.01.00' '334.03.01.181.00.00'
#  '387.01.01.000.00.01' '411.04.02.000.00.02' '449.01.01.000.04.00'
#  '387.01.01.000.00.02' '461.01.01.000.01.08' '362.01.01.000.01.02'
#  '461.01.01.000.01.10' '334.02.01.026.00.00' '334.02.01.000.06.01'
#  '474.01.02.000.00.00' '474.01.01.000.00.00' '421.03.02.000.08.01'
#  '338.01.01.194.01.00']

# %%
print(result_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 973 entries, 0 to 972
# Data columns (total 66 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   WirtEinh                973 non-null    int64
#  1   EQ_übergeordnet         364 non-null    float64
#  2   Equipment               973 non-null    int64
#  3   EQ-Bezeichnung          973 non-null    object
#  4   EQ-Klasse               973 non-null    int64
#  5   EQ-Klasse-Bezeichnung   973 non-null    object
#  6   Gewerk                  973 non-null    object
#  7   Anlagenausprägung       973 non-null    object
#  8   EQ-Menge                973 non-null    int64
#  9   EQ-Merkmal_001          506 non-null    object
#  10  EQ-Merkmal_002          321 non-null    object
#  11  EQ-Merkmal_003          627 non-null    object
#  12  EQ-Merkmal_004          681 non-null    object
#  13  EQ-Merkmal_005          419 non-null    object
#  14  EQ-Merkmal_006          378 non-null    object
#  15  EQ-Merkmal_007          230 non-null    object
#  16  EQ-Merkmal_008          154 non-null    object
#  17  EQ-Merkmal_009          122 non-null    object
#  18  EQ-Merkmal_010          104 non-null    object
#  19  EQ-Merkmal_011          94 non-null     object
#  20  EQ-Merkmal_012          30 non-null     object
#  21  EQ-Merkmal_013          24 non-null     object
#  22  EQ-Merkmal_014          86 non-null     object
#  23  EQ-Merkmal_015          80 non-null     object
#  24  EQ-Merkmal_016          43 non-null     object
#  25  EQ-Merkmal_017          14 non-null     object
#  26  EQ-Merkmal_018          53 non-null     object
#  27  EQ-Merkmal_019          20 non-null     object
#  28  EQ-Merkmal_020          65 non-null     object
#  29  EQ-Merkmal_021          50 non-null     object
#  30  EQ-Merkmal_022          24 non-null     object
#  31  EQ-Merkmal_023          26 non-null     object
#  32  EQ-Merkmal_024          51 non-null     object
#  33  EQ-Merkmal_025          49 non-null     object
#  34  EQ-Merkmal_026          8 non-null      object
#  35  EQ-Merkmal_027          40 non-null     object
#  36  EQ-Merkmal_028          42 non-null     object
#  37  EQ-Merkmal_029          4 non-null      object
#  38  EQ-Merkmal_030          1 non-null      object
#  39  EQ-Merkmal_031          0 non-null      float64
#  40  EQ-Merkmal_032          0 non-null      float64
#  41  EQ-Merkmal_033          1 non-null      object
#  42  EQ-Merkmal_034          0 non-null      float64
#  43  EQ-Merkmal_035          0 non-null      float64
#  44  EQ-Merkmal_036          1 non-null      object
#  45  EQ-Merkmal_037          1 non-null      object
#  46  EQ-Merkmal_038          1 non-null      object
#  47  EQ-Merkmal_039          0 non-null      float64
#  48  EQ-Merkmal_040          0 non-null      float64
#  49  EQ-Merkmal_041          0 non-null      float64
#  50  EQ-Merkmal_042          0 non-null      float64
#  51  EQ-Merkmal_043          0 non-null      float64
#  52  EQ-Merkmal_044          0 non-null      float64
#  53  EQ-Merkmal_045          0 non-null      float64
#  54  EQ-Merkmal_046          0 non-null      float64
#  55  EQ-Merkmal_047          0 non-null      float64
#  56  EQ-Merkmal_048          0 non-null      float64
#  57  EQ-Merkmal_049          0 non-null      float64
#  58  EQ-Merkmal_050          0 non-null      float64
#  59  EQ-Merkmal_051          0 non-null      float64
#  60  EQ-Merkmal_052          0 non-null      float64
#  61  Extracted_Kostengruppe  913 non-null    object
#  62  Artikelnummer_Assigned  92 non-null     object
#  63  Match_Score             973 non-null    int64
#  64  Match_Category          92 non-null     object
#  65  Match_Path              0 non-null      object
# dtypes: float64(19), int64(5), object(42)
# memory usage: 501.8+ KB
# None

# %% [markdown]
# **Note: Fuzzy match is NOT enough.**
